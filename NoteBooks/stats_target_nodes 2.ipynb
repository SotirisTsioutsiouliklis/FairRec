# %%
import networkx as nx
import pandas as pd
import sys
import os.path
from os import path
from collections import defaultdict

# %%
scores_files = ["fair", "hybrid_node2vec", "dyadic_fair", "hybrid_balanced_node2vec", "node2vec", "fairwalk", "random"]
names = ["FREC", "E_FREC", "PREC", "E_PREC", "n2v", "FairWalk", "Random"]
def compute_stats(dataset):
    red_pr = pd.read_csv(dataset + "/red_absorbing_probabilities.csv")
    pr = pd.read_csv(dataset + "/out_pagerank.csv")
    com = pd.read_csv(dataset + "/out_community.txt", names=["Nodes", "Community"], sep='\\s+', skiprows=1)
    f = open(dataset + "/out_graph.txt")
    lines = f.readlines()
    f.close()
    G = nx.parse_edgelist(lines[1:], nodetype=int, create_using=nx.DiGraph)

    names = None
    if path.exists(dataset + "/names.txt"):
        names = pd.read_csv(dataset + "/names.txt", sep='\t')
#         print(names.info())

    # print(red_pr.info())
    # print(pr.info())
    # print(com.info())

    for sf in scores_files:
        print(sf)
        df = pd.read_csv(dataset + "/" + f"sc_{sf}.csv")
        pr_ = list()
        rpr_ = list()
        homophily = list()
        distance = list()
        no_exist = list()
        ratio = list()
        i = 0
        error = False
        nE = 0
        for index, row in df.iterrows():
            if row['Rounds'] == -1: continue
            edges = list(eval(str(row["Edges"])))
            for e in edges:
                F = False
                try:
                    try:
                        length = len(nx.shortest_path(G, source=e[1], target=e[0])) - 1
                        try:
                            comm = com.loc[com['Nodes'] == e[1]].iloc[0]["Community"]
                            ratio.append(comm) 
                        except:
                            F = True
                        if not F:
                            distance.append(length)
                            x = 0
                            neighs = [n for n in G.neighbors(e[1])]
                            for n in neighs:
                                if com.loc[com['Nodes'] == n].iloc[0]["Community"] == comm:
                                    x+=1    
                            if len(neighs) > 0:
                                homophily.append(float(x / len(neighs)))
                            else:
                                homophily.append(0)
                        try:
                            if not F:
                                pr_.append(round(pr[pr["Nodes"] == e[1]].iloc[0]["Pagerank"], 4))
                                rpr_.append(round(red_pr[red_pr["Nodes"] == e[1]].iloc[0]["Red Pagerank"], 4))
                        except:
                            F = True
                    except:
                        nE+=1
                except Exception:
                     pass
        data = list()
        for i in range(0, len(distance)):
            no_exist.append(nE)
        print(len(distance))
        print(len(no_exist))
        print(len(pr_))
        print(len(rpr_))
        print(len(homophily))
        print(len(ratio))
        y = dict(zip(["Distance", "Inf Dist", "PageRank", "Red PageRank", "Homophily", "Red Ratio"], 
                     [distance, no_exist, pr_, rpr_, homophily, ratio]))
        df = pd.DataFrame(y, columns = ["Distance", "Inf Dist", "PageRank", "Red PageRank", 
                                        "Homophily", "Red Ratio"])
        df.to_csv(f"{dataset}/{sf}_stats1.csv", index=False)

# %%
compute_stats("books")

# %%
compute_stats("blogs")

# %%
compute_stats("twitter")

# %%
compute_stats("dblp_new_pubs")
# Out:
# fair
# 328
# 328
# 328
# 328
# 328
# 328
# hybrid_node2vec
# 337
# 337
# 337
# 337
# 337
# 337
# dyadic_fair
# 429
# 429
# 429
# 429
# 429
# 429
# hybrid_balanced_node2vec
# 381
# 381
# 381
# 381
# 381
# 381
# node2vec
# 1360
# 1360
# 1360
# 1360
# 1360
# 1360
# fairwalk
# 5726
# 5726
# 5726
# 5726
# 5726
# 5726
# random
# 961
# 961
# 961
# 961
# 961
# 961

# %%
compute_stats("dblp_new_gender")
# Out:
# fair
# 1739
# 1739
# 1739
# 1739
# 1739
# 1739
# hybrid_node2vec
# 1415
# 1415
# 1415
# 1415
# 1415
# 1415
# dyadic_fair
# 1231
# 1231
# 1231
# 1231
# 1231
# 1231
# hybrid_balanced_node2vec
# 1012
# 1012
# 1012
# 1012
# 1012
# 1012
# node2vec
# 1404
# 1404
# 1404
# 1404
# 1404
# 1404
# fairwalk
# 6199
# 6199
# 6199
# 6199
# 6199
# 6199
# random
# 954
# 954
# 954
# 954
# 954
# 954

# %%
def final(dataset):
    results = [[] for i in range(0, len(scores_files))]
    i = 0
    for sf in scores_files:
        df = pd.read_csv(dataset + "/" + f"{sf}_stats1.csv")
        mean = df.rename(columns={'Distance': 'Mean Distance', 'PageRank': 'Mean PageRank',
                                    'Red PageRank': 'Mean Red PageRank', 'Homophily': 'Mean Homophily'})
        median = df.rename(columns={'Distance': 'Median Distance', 'PageRank': 'Median PageRank',
                                    'Red PageRank': 'Median Red PageRank', 'Homophily': 'Median Homophily'})
        max = df.rename(columns={'Distance': 'Max Distance', 'PageRank': 'Max PageRank',
                                    'Red PageRank': 'Max Red Pagerank', 'Homophily': 'Max Homophily'})
        dfm = mean.mean()
        dfmed = median.median()
        dfmax = max.max()
    
        for j in range(0, 5):
            if j == 1:
                results[i].append(dfm.iloc[1]/len(dfm))
                continue
            results[i].append(dfm.iloc[j])
            results[i].append(dfmed.iloc[j])
            results[i].append(dfmax.iloc[j])
        results[i].append(dfm.iloc[5])
        i+=1
    
    y = dict(zip(names, results))
    df = pd.DataFrame(y)
    #print(results)
    df_tr = df.transpose()
    df_tr.rename(columns={0: "Mean Distance", 1: "Median Distance", 2: "Max Distance", 3: "Inf Dist", 
                          4: "Mean PageRank", 5: "Median Pagerank", 6: "Max PageRank", 7: "Mean Red PageRank", 
                          8: "Median Red Pagerank", 9: "Max Red PageRank", 10: "Mean Homophily", 
                          11: "Median Homophily", 12: "Max Homophily",  13: "Red Ratio"}, 
                 inplace=True)
    del df_tr["Inf Dist"]
    df_tr = df_tr.round(4)
    df_tr.insert(0, "Algo", names, True)
    return df_tr

# %%
final("books")
# Out:
#               Algo  Mean Distance  Median Distance  Max Distance  \
# FREC          FREC         3.4444              4.0           4.0
# E_FREC      E_FREC         3.4111              4.0           4.0
# PREC          PREC         3.9222              4.0           4.0
# E_PREC      E_PREC         3.8667              4.0           4.0
# n2v            n2v         2.9889              3.0           4.0
# FairWalk  FairWalk         2.6333              2.0           4.0
# Random      Random         3.2614              3.0           6.0
#
#           Mean PageRank  Median Pagerank  Max PageRank  Mean Red PageRank  \
# FREC             0.0118           0.0088        0.0263             0.9005
# E_FREC           0.0138           0.0114        0.0263             0.8955
# PREC             0.0138           0.0108        0.0283             0.6056
# E_PREC           0.0163           0.0166        0.0283             0.6025
# n2v              0.0202           0.0189        0.0283             0.5185
# FairWalk         0.0106           0.0085        0.0280             0.3920
# Random           0.0103           0.0082        0.0280             0.3813
#
#           Median Red Pagerank  Max Red PageRank  Mean Homophily  \
# FREC                   0.9486            0.9736          0.9195
# E_FREC                 0.9363            0.9736          0.9091
# PREC                   0.8064            0.9591          0.9074
# E_PREC                 0.8064            0.9591          0.8971
# n2v                    0.7581            0.9597          0.9324
# FairWalk               0.0779            0.9704          0.9395
# Random                 0.0756            0.9736          0.9492
#
#           Median Homophily  Max Homophily  Red Ratio
# FREC                 1.000            1.0     0.9444
# E_FREC               1.000            1.0     0.9444
# PREC                 1.000            1.0     0.6111
# E_PREC               0.975            1.0     0.6111
# n2v                  1.000            1.0     0.5333
# FairWalk             1.000            1.0     0.3667
# Random               1.000            1.0     0.3523

# %%
final("blogs")
# Out:
#               Algo  Mean Distance  Median Distance  Max Distance  \
# FREC          FREC         4.0234              4.0           7.0
# E_FREC      E_FREC         2.6935              3.0           5.0
# PREC          PREC         4.4005              4.0           7.0
# E_PREC      E_PREC         2.9117              3.0           5.0
# n2v            n2v         2.6457              2.0           6.0
# FairWalk  FairWalk         2.9143              3.0           5.0
# Random      Random         2.9172              3.0           7.0
#
#           Mean PageRank  Median Pagerank  Max PageRank  Mean Red PageRank  \
# FREC             0.0002           0.0002        0.0003             0.6221
# E_FREC           0.0012           0.0014        0.0026             0.5436
# PREC             0.0002           0.0002        0.0005             0.6203
# E_PREC           0.0014           0.0014        0.0026             0.5305
# n2v              0.0024           0.0018        0.0100             0.4479
# FairWalk         0.0005           0.0003        0.0040             0.4467
# Random           0.0006           0.0003        0.0100             0.4412
#
#           Median Red Pagerank  Max Red PageRank  Mean Homophily  \
# FREC                   0.6201            0.6392          1.0000
# E_FREC                 0.5374            0.6392          0.9459
# PREC                   0.6201            0.6392          1.0000
# E_PREC                 0.5313            0.6392          0.9364
# n2v                    0.5045            0.5653          0.8024
# FairWalk               0.5125            0.6140          0.8936
# Random                 0.5068            0.6392          0.8936
#
#           Median Homophily  Max Homophily  Red Ratio
# FREC                1.0000            1.0     1.0000
# E_FREC              0.9571            1.0     1.0000
# PREC                1.0000            1.0     0.9977
# E_PREC              0.9524            1.0     0.9928
# n2v                 0.9231            1.0     0.8924
# FairWalk            0.9954            1.0     0.8200
# Random              1.0000            1.0     0.7959

# %%
final("twitter")
# Out:
#               Algo  Mean Distance  Median Distance  Max Distance  \
# FREC          FREC         8.8733              9.0          14.0
# E_FREC      E_FREC         7.5702              8.0          14.0
# PREC          PREC         8.7421              9.0          14.0
# E_PREC      E_PREC         8.0419              8.0          14.0
# n2v            n2v         6.7230              7.0          13.0
# FairWalk  FairWalk         4.0765              4.0          12.0
# Random      Random         6.3267              6.0          12.0
#
#           Mean PageRank  Median Pagerank  Max PageRank  Mean Red PageRank  \
# FREC             0.0001           0.0000        0.0027             0.8353
# E_FREC           0.0004           0.0003        0.0027             0.8133
# PREC             0.0002           0.0001        0.0018             0.5140
# E_PREC           0.0005           0.0003        0.0027             0.5148
# n2v              0.0009           0.0007        0.0033             0.4966
# FairWalk         0.0001           0.0000        0.0033             0.5465
# Random           0.0001           0.0000        0.0027             0.5338
#
#           Median Red Pagerank  Max Red PageRank  Mean Homophily  \
# FREC                   0.8451            0.8771          0.9997
# E_FREC                 0.8178            0.8771          0.9984
# PREC                   0.3314            0.8554          0.9986
# E_PREC                 0.3594            0.8554          0.9973
# n2v                    0.3594            0.8178          0.9217
# FairWalk               0.6222            0.8554          0.9539
# Random                 0.4155            0.8451          0.9780
#
#           Median Homophily  Max Homophily  Red Ratio
# FREC                   1.0            1.0     1.0000
# E_FREC                 1.0            1.0     0.9988
# PREC                   1.0            1.0     0.4796
# E_PREC                 1.0            1.0     0.4796
# n2v                    1.0            1.0     0.3798
# FairWalk               1.0            1.0     0.5297
# Random                 1.0            1.0     0.4904

# %%
final("dblp_new_pubs")
# Out:
#               Algo  Mean Distance  Median Distance  Max Distance  \
# FREC          FREC         4.2957              4.0           9.0
# E_FREC      E_FREC         4.2463              4.0          11.0
# PREC          PREC         4.3660              4.0          14.0
# E_PREC      E_PREC         4.3202              4.0          16.0
# n2v            n2v         4.4199              4.0          18.0
# FairWalk  FairWalk         3.8496              4.0          19.0
# Random      Random         6.1592              6.0          17.0
#
#           Mean PageRank  Median Pagerank  Max PageRank  Mean Red PageRank  \
# FREC                0.0              0.0        0.0001             0.4695
# E_FREC              0.0              0.0        0.0001             0.4564
# PREC                0.0              0.0        0.0001             0.2903
# E_PREC              0.0              0.0        0.0001             0.3149
# n2v                 0.0              0.0        0.0004             0.1863
# FairWalk            0.0              0.0        0.0002             0.2080
# Random              0.0              0.0        0.0001             0.1980
#
#           Median Red Pagerank  Max Red PageRank  Mean Homophily  \
# FREC                   0.5468            0.5795          0.6260
# E_FREC                 0.5081            0.5795          0.5984
# PREC                   0.1595            0.5795          0.8075
# E_PREC                 0.2924            0.5795          0.7484
# n2v                    0.1844            0.5239          0.8355
# FairWalk               0.1845            0.5795          0.7387
# Random                 0.1823            0.4157          0.7901
#
#           Median Homophily  Max Homophily  Red Ratio
# FREC                0.7500            1.0     0.9268
# E_FREC              0.7500            1.0     0.9288
# PREC                1.0000            1.0     0.4545
# E_PREC              0.8125            1.0     0.5223
# n2v                 0.8333            1.0     0.0287
# FairWalk            0.8182            1.0     0.1390
# Random              0.8519            1.0     0.1093

# %%
final("dblp_new_gender")
# Out:
#               Algo  Mean Distance  Median Distance  Max Distance  \
# FREC          FREC         5.5980              5.0          18.0
# E_FREC      E_FREC         4.9767              4.0          17.0
# PREC          PREC         5.6101              5.0          17.0
# E_PREC      E_PREC         4.9891              4.0          18.0
# n2v            n2v         4.5684              4.0          16.0
# FairWalk  FairWalk         4.0555              4.0          16.0
# Random      Random         6.0493              6.0          19.0
#
#           Mean PageRank  Median Pagerank  Max PageRank  Mean Red PageRank  \
# FREC                0.0              0.0        0.0001             0.5399
# E_FREC              0.0              0.0        0.0001             0.5149
# PREC                0.0              0.0        0.0001             0.4943
# E_PREC              0.0              0.0        0.0001             0.4741
# n2v                 0.0              0.0        0.0004             0.2988
# FairWalk            0.0              0.0        0.0001             0.2600
# Random              0.0              0.0        0.0001             0.2487
#
#           Median Red Pagerank  Max Red PageRank  Mean Homophily  \
# FREC                   0.5527            0.6813          0.8890
# E_FREC                 0.5202            0.6813          0.8112
# PREC                   0.5483            0.6231          0.9018
# E_PREC                 0.4941            0.6231          0.8226
# n2v                    0.3493            0.5202          0.4122
# FairWalk               0.2189            0.6323          0.5951
# Random                 0.2192            0.5930          0.6566
#
#           Median Homophily  Max Homophily  Red Ratio
# FREC                1.0000            1.0     0.9948
# E_FREC              1.0000            1.0     0.9929
# PREC                1.0000            1.0     0.8846
# E_PREC              1.0000            1.0     0.8923
# n2v                 0.1667            1.0     0.6168
# FairWalk            0.7391            1.0     0.2944
# Random              0.7368            1.0     0.2285

# %%
# print(final("books").to_latex(index=False))
# print(final("blogs").to_latex(index=False))
# print(final("twitter").to_latex(index=False))
print(final("dblp_new_pubs").to_latex(index=False))
# print(final("dblp_new_gender").to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrrrrrrrrrr}
# \toprule
#      Algo &  Mean Distance &  Median Distance &  Max Distance &  Mean PageRank &  Median Pagerank &  Max PageRank &  Mean Red PageRank &  Median Red Pagerank &  Max Red PageRank &  Mean Homophily &  Median Homophily &  Max Homophily &  Red Ratio \\
# \midrule
#      FREC &         4.2957 &              4.0 &           9.0 &            0.0 &              0.0 &        0.0001 &             0.4695 &               0.5468 &            0.5795 &          0.6260 &            0.7500 &            1.0 &     0.9268 \\
#    E\_FREC &         4.2463 &              4.0 &          11.0 &            0.0 &              0.0 &        0.0001 &             0.4564 &               0.5081 &            0.5795 &          0.5984 &            0.7500 &            1.0 &     0.9288 \\
#      PREC &         4.3660 &              4.0 &          14.0 &            0.0 &              0.0 &        0.0001 &             0.2903 &               0.1595 &            0.5795 &          0.8075 &            1.0000 &            1.0 &     0.4545 \\
#    E\_PREC &         4.3202 &              4.0 &          16.0 &            0.0 &              0.0 &        0.0001 &             0.3149 &               0.2924 &            0.5795 &          0.7484 &            0.8125 &            1.0 &     0.5223 \\
#       n2v &         4.4199 &              4.0 &          18.0 &            0.0 &              0.0 &        0.0004 &             0.1863 &               0.1844 &            0.5239 &          0.8355 &            0.8333 &            1.0 &     0.0287 \\
#  FairWalk &         3.8496 &              4.0 &          19.0 &            0.0 &              0.0 &        0.0002 &             0.2080 &               0.1845 &            0.5795 &          0.7387 &            0.8182 &            1.0 &     0.1390 \\
#    Random &         6.1592 &              6.0 &          17.0 &            0.0 &              0.0 &        0.0001 &             0.1980 &               0.1823 &            0.4157 &          0.7901 &            0.8519 &            1.0 &     0.1093 \\
# \bottomrule
# \end{tabular}

# %%
x = {"A": [1,2,3], "B": [2,3,4]}
algo_names = ["FREC", "E-FREC", "PREC", "E-PREC", "n2v", "FairWalk"]
df = pd.DataFrame(x, columns = ["A", "B"])
df
columns_ = [1, 2, 3 ,4 ,5, 6]
fruit_dictionary = dict(zip(algo_names, columns_))
# data = [{algo_names[i]: columns_[i]} for i in range(0, len(algo_names))]
fruit_dictionary
# Out:
# {'FREC': 1, 'E-FREC': 2, 'PREC': 3, 'E-PREC': 4, 'n2v': 5, 'FairWalk': 6}

# %%
pair_files = ["sc_fair.csv", "sc_hybrid_node2vec.csv", "sc_dyadic_fair.csv", "sc_hybrid_balanced_node2vec.csv",
              "sc_node2vec.csv", "sc_fairwalk.csv"]
algo_names = ["FREC", "E-FREC", "PREC", "E-PREC", "n2v", "FairWalk"]
def table_best_target_nodes(dataset, sep=" "):
    rounds = 10
    nodes = dict()
    columns_ = list()
    
    names = None
    if path.exists(dataset + "/names.txt"):
        names = pd.read_csv(dataset + "/names.txt", sep='\t')
    i = 0
    for sf in pair_files:
        dfs = dict()
        df = pd.read_csv(f"{dataset}/{sf}")
        edges = list()
        for r in range(1, rounds + 1):
            es = eval(df["Edges"][r])
            edges.extend(es)
        for e in edges:
            tgt = names[names['Node_id'] == e[1]].iloc[0]["Author_Name"]
            if tgt in dfs:
                dfs[tgt]+=1
            else:
                dfs[tgt] = 1
        dfs = dict(sorted(dfs.items(), key=lambda item: item[1], reverse=True))
        sorted_keys = sorted(dfs, key=dfs.get, reverse=True)
        col = list()
        c = 0
        for k in sorted_keys:
            col.append(k + f" ({str(dfs[k])})")
            c+=1
            if c==20:
                break
        columns_.append(col)
        i+=1
    y = dict(zip(algo_names, columns_))
    df = pd.DataFrame(y, columns = algo_names)
    print(df.to_latex(index=False))

# %%
table_best_target_nodes("dblp_new_pubs")
# Out:
# \begin{tabular}{llllll}
# \toprule
#                          FREC &                     E-FREC &                     PREC &                      E-PREC &                              n2v &              FairWalk \\
# \midrule
#          Xiaoqing Huang (937) &           Jincai Lai (935) &     Xiaoqing Huang (667) &            Jincai Lai (704) &         Daniel D. Corkill (1033) &   Qinghua Zheng (620) \\
#                Pin Xiao (875) &       Xiaoqing Huang (935) &           Pin Xiao (617) &        Xiaoqing Huang (665) &             Amanda Gentzel (980) &        Lina Yao (421) \\
#           Corbin Rosset (747) &            Haoyu Han (872) &      Corbin Rosset (519) &             Haoyu Han (622) &            Fotis Psallidas (970) &   Sen Wang 0001 (388) \\
#          Gale Yan Huang (702) &             Pin Xiao (858) &     Gale Yan Huang (489) &              Pin Xiao (604) &             Lisa Friedland (943) &       Yang Chen (365) \\
#               Haoyu Han (599) &         Tianqiao Liu (721) &       Xin Jin 0001 (445) &          Tianqiao Liu (514) &             Subru Krishnan (848) &  Meng Wang 0009 (313) \\
#            Tianqiao Liu (578) &               Mi Luo (672) &          Haoyu Han (418) &                Mi Luo (478) &             Meng Wang 0009 (829) &      Buyue Qian (291) \\
#           Brent Ellwein (571) &           Xiaosen Li (621) &       Tianqiao Liu (395) &            Xiaosen Li (435) &            David D. Jensen (810) &       Ning Wang (275) \\
#             Zongyue Qin (484) &        Corbin Rosset (532) &      Brent Ellwein (389) &          Haeseung Seo (359) &                  Yiwen Zhu (765) &       Guilin Qi (268) \\
#            Shangchen Du (448) &         Haeseung Seo (500) &        Alex Memory (359) &         Corbin Rosset (356) &            Duen Horng Chau (762) &      Jundong Li (254) \\
#             Diandian Gu (448) &         Shangchen Du (448) &          Oguz Kaya (341) &           Alex Memory (332) &    Pannagadatta Shivaswamy (759) &     Haomin Shen (220) \\
#          Julian Gibbons (422) &       Gale Yan Huang (377) &        Zongyue Qin (339) &          Shangchen Du (322) &               Cong Yu 0001 (524) &     Jishang Wei (216) \\
#            Bojan Karlas (361) &            Jiahao Wu (344) &      Shubhomoy Das (326) &       Fotis Psallidas (311) &              Shanshan Ying (487) &    Jun Liu 0002 (209) \\
#              Alan Green (355) &         Goutham Deva (343) &      Andrew Emmott (326) &          Xin Jin 0001 (307) &        Shauheen Zahirazami (378) &    Wenqiang Liu (209) \\
#           Diana Doherty (338) &         Pradap Konda (315) &       Shangchen Du (322) &          Goutham Deva (249) &                Dipak Gupta (346) &        Siyu Yao (209) \\
#           Huazheng Wang (337) &   Alexander Gorovits (307) &        Diandian Gu (322) &             Jiahao Wu (247) &               Jay Yoon Lee (346) &  Wei Zhang 0053 (208) \\
#  MaryAnn Van Valkenburg (299) &        Brent Ellwein (304) &     Ted E. Senator (306) &        Gale Yan Huang (240) &  Mohammad Zeeshan Siddiqui (267) &    Lingyun Song (208) \\
#                  Mi Luo (298) &          Diandian Gu (264) &     Julian Gibbons (280) &             Yiwen Zhu (238) &              Yin Yang 0001 (237) &       Xiaoyu Li (202) \\
#               Sam Burke (294) &  Guoqiang Jerry Chen (258) &  Henry G. Goldberg (259) &  Rudolph L. Mappus IV (235) &                Zhenhao Hua (237) &   Tetsuya Sakai (141) \\
#              Xiaosen Li (288) &          Yun Ma 0003 (248) &      Diana Doherty (245) &       Angelika Kimmig (234) &               Wei Liu 0005 (234) &      Kaize Ding (137) \\
#        Nicholas Fajardo (255) &         Jordan Lewis (235) &       Bojan Karlas (245) &          Pradap Konda (226) &               Martin Wicke (224) &         Yang Li (133) \\
# \bottomrule
# \end{tabular}

# %%
table_best_target_nodes("dblp_new_gender")
# Out:
# \begin{tabular}{llllll}
# \toprule
#                           FREC &                   E-FREC &                     PREC &                   E-PREC &                              n2v &              FairWalk \\
# \midrule
#              Limeng Cui (1444) &        Limeng Cui (1121) &         Limeng Cui (956) &         Limeng Cui (710) &           Fotis Psallidas (1041) &   Qinghua Zheng (780) \\
#             Yi-Feng Lan (1257) &       Yi-Feng Lan (1058) &        Yi-Feng Lan (856) &        Yi-Feng Lan (704) &             Amanda Gentzel (940) &        Lina Yao (564) \\
#            Hsu-Chao Lai (1058) &       Dongwon Lee (1004) &       Hsu-Chao Lai (715) &        Dongwon Lee (671) &             Lisa Friedland (896) &   Sen Wang 0001 (509) \\
#             Dongwon Lee (1012) &  Wush Chi-Hsuan Wu (931) &        Dongwon Lee (679) &  Wush Chi-Hsuan Wu (624) &             Subru Krishnan (827) &       Yang Chen (468) \\
#             Haeseung Seo (915) &       Haeseung Seo (915) &       Haeseung Seo (613) &       Haeseung Seo (613) &          Daniel D. Corkill (798) &  Meng Wang 0009 (390) \\
#             Shao-Heng Ko (896) &       Maryam Tabar (727) &       Shao-Heng Ko (605) &       Maryam Tabar (497) &             Meng Wang 0009 (788) &      Buyue Qian (368) \\
#        Wush Chi-Hsuan Wu (757) &     Ming-Feng Tsai (633) &  Wush Chi-Hsuan Wu (522) &     Ming-Feng Tsai (443) &                  Yiwen Zhu (760) &       Guilin Qi (329) \\
#           Yen-Chieh Lien (528) &         Yaowei Yan (575) &     Yen-Chieh Lien (347) &         Yaowei Yan (400) &                David Mares (746) &       Ning Wang (323) \\
#             Chi-Chun Lin (477) &           Meiyu Lu (516) &       Chi-Chun Lin (325) &        Saket Sathe (392) &            David D. Jensen (684) &     Haomin Shen (300) \\
#             Ying-Ju Chen (450) &     Yen-Chieh Lien (513) &       Ilari Shafer (325) &           Meiyu Lu (360) &    Pannagadatta Shivaswamy (561) &      Jundong Li (270) \\
#          Rawia Awadallah (366) &       Chi-Chun Lin (477) &           Boyi Hou (324) &       Chi-Chun Lin (325) &      Rama Kumar Pasumarthi (476) &     Jishang Wei (261) \\
#              Byungju Kim (364) &      Chuan-Ju Wang (448) &      Honglei Zhang (315) &     Yen-Chieh Lien (323) &                Dipak Gupta (469) &       Xiaoyu Li (256) \\
#            Chuan-Ju Wang (361) &       Shao-Heng Ko (404) &       Ying-Ju Chen (307) &      Chuan-Ju Wang (304) &              Shanshan Ying (440) &    Wenqiang Liu (252) \\
#             Deokmin Haam (260) &      Pranjul Yadav (378) &        Saket Sathe (273) &      Honglei Zhang (274) &            Duen Horng Chau (436) &  Wei Zhang 0053 (252) \\
#              Hao-Yi Chih (244) &      Shanshan Ying (346) &      Chuan-Ju Wang (251) &        Zhichao Han (264) &          Gregory R. Ganger (373) &    Lingyun Song (252) \\
#               Yaowei Yan (233) &       Hsu-Chao Lai (344) &        Ruochun Jin (250) &      Shanshan Ying (261) &                Hua Lu 0001 (344) &        Siyu Yao (252) \\
#            Jae-woong Lee (207) &      Ying-Chun Lin (339) &        Byungju Kim (222) &      Pranjul Yadav (252) &        Shauheen Zahirazami (338) &    Jun Liu 0002 (251) \\
#           Ming-Feng Tsai (204) &    Rawia Awadallah (267) &    Rawia Awadallah (221) &       Shao-Heng Ko (249) &              Miles Osborne (336) &   Tetsuya Sakai (161) \\
#          Sedigheh Eslami (200) &   Shobeir Fakhraei (208) &         Luyang Liu (206) &      Ying-Chun Lin (230) &  Mohammad Zeeshan Siddiqui (330) &      Kaize Ding (156) \\
#  Alfan Farizki Wicaksono (195) &  Franciska de Jong (202) &       Chunkai Wang (198) &       Hsu-Chao Lai (229) &               Jay Yoon Lee (323) &    Yinlin Jiang (140) \\
# \bottomrule
# \end{tabular}
