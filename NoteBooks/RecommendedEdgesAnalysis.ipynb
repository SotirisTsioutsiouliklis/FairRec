# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import os.path
from statistics import median
import sys
from os import path
sns.set_theme(style="whitegrid")

# %%
def get_target_nodes_features(dataset, policy):
    # To get distance ##################
    f = open(f"{dataset}/out_graph.txt")
    lines = f.readlines()
    f.close()
    G = nx.parse_edgelist(lines[1:], nodetype=int, create_using=nx.DiGraph)
    trgs = dict()
    min_d = dict()
    sum_d = dict()
    max_d = dict()
    no_exist = dict()
    median_d = dict()
    ####################################
    
    round_stats = pd.read_csv(f"{dataset}/sc_{policy}.csv").drop(axis=0, labels=[0])
    target_nodes = dict()
    for index, row in round_stats.iterrows():
        edges = eval(row["Edges"])
        # ---------------------------------------------------
        for edge in edges:
            target = edge[1]
            if target not in target_nodes:
                target_nodes[target] = [0 for i in range(10)]
            target_nodes[target][row["Rounds"]] += 1
        # ---------------------------------------------------
        # To get distance #####################
        for e in edges:
            trgs.setdefault(e[1], 0)
            min_d.setdefault(e[1], sys.maxsize)
            sum_d.setdefault(e[1], 0)
            max_d.setdefault(e[1], 0)
            no_exist.setdefault(e[1], 0)
            median_d.setdefault(e[1], list())
            trgs[e[1]] += 1
            try:
                length = len(nx.shortest_path(G, source=e[1], target=e[0])) - 1
                sum_d[e[1]] += length
                if min_d[e[1]] > length: min_d[e[1]] = length
                if max_d[e[1]] < length: max_d[e[1]] = length
                median_d[e[1]].append(length)
            except nx.NetworkXNoPath:
                no_exist[e[1]] += 1
        #######################################
    totals = dict()
    for node in target_nodes:
        totals[node] = sum(target_nodes[node])
    nodes = list(totals.keys())
    values = list(totals.values())
    dd = {
        "Nodes": nodes,
        "times": values
    }
    df = pd.DataFrame(dd)
    nodes_info = pd.read_csv(f"{dataset}/nodeQualityFeatures.txt", sep="\t")
    nodes_info['out_homophily'] = [row['redNeighborsOutRatio'] if row['group'] == 1 else 1 - row['redNeighborsOutRatio']
                               for i, row in nodes_info.iterrows()]
    df = df.join(nodes_info.set_index("nodeId"), on="Nodes")
    
    # To get distance ########################
    data = list()
    for k,v in trgs.items():
        temp_median = median(median_d[k]) if median_d[k] else float("NaN")
        data.append([k, min_d[k], max_d[k], round(sum_d[k]/trgs[k],3), temp_median, no_exist[k]])
    df_d = pd.DataFrame(data, columns=['Nodes', 'MinDistance', "MaxDistance", "AverageDistance", "MedianDistance", "NoExistsDistance"])
    df = df.join(df_d.set_index("Nodes"), on="Nodes")
    ##########################################
    
    df = df.sort_values(axis=0, by="times", ascending=False)
    
    return df

# %% [markdown]
# # Node2vec

# %%
books = get_target_nodes_features("books", "node2vec")
blogs = get_target_nodes_features("blogs", "node2vec")
dblp = get_target_nodes_features("dblp_course", "node2vec")
dblp_n2v = get_target_nodes_features("dblp_course", "node2vec")
twitter = get_target_nodes_features("twitter", "node2vec")

# %%
blogs_n2v.head()
# Out:
#     Nodes  times  pagerank  redPagerank  group  inDegree  outDegree  \
# 0       0    120  0.000244     0.565289      1         0         26
# 6     252     94  0.001305     0.505282      1        67        103
# 4     542     86  0.002178     0.431412      1        57          5
# 8     583     81  0.005510     0.295485      1       109         24
# 10    282     81  0.001782     0.551821      1        79         92
#
#     redNeighborsInRatio  redNeighborsOutRatio  out_homophily  MinDistance  \
# 0              0.500000              0.923077       0.923077            2
# 6              0.985075              0.834951       0.834951            2
# 4              1.000000              1.000000       1.000000            2
# 8              0.990826              0.000000       0.000000            2
# 10             1.000000              0.978261       0.978261            2
#
#     MaxDistance  AverageDistance  MedianDistance  NoExistsDistance
# 0             4            2.217             2.0                19
# 6             5            1.734             3.0                31
# 4             7            1.407             3.0                51
# 8             4            0.951             2.0                50
# 10            6            1.765             3.0                28

# %%
books.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#           Nodes     times  pagerank  redPagerank     group   inDegree  \
# mean  52.260870  3.913043  0.019081     0.518181  0.521739  15.260870
# std   26.377017  2.043016  0.005917     0.445531  0.510754   5.370097
# min    2.000000  1.000000  0.008221     0.019940  0.000000   5.000000
# 50%   50.000000  4.000000  0.018066     0.772748  1.000000  15.000000
# max   91.000000  7.000000  0.028284     0.970356  1.000000  24.000000
#
#       outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean  15.260870             0.521251              0.521251       0.956033
# std    5.370097             0.478876              0.478876       0.111241
# min    5.000000             0.000000              0.000000       0.500000
# 50%   15.000000             0.800000              0.800000       1.000000
# max   24.000000             1.000000              1.000000       1.000000
#
#       MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean     2.173913     3.478261         2.796174        2.760870
# std      0.491026     0.790257         0.543910        0.720946
# min      2.000000     2.000000         2.000000        2.000000
# 50%      2.000000     4.000000         2.833000        2.500000
# max      4.000000     4.000000         4.000000        4.000000
#
#       NoExistsDistance
# mean               0.0
# std                0.0
# min                0.0
# 50%                0.0
# max                0.0

# %%
books_top = books.loc[books['times'] >= 6]
temp = books_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((books_top.times * books_top.group) / sum(books_top.times)):.6f}")
# Out:
# 2.989857 & 3.071429 & 3.714286 & 0.000000 & 0.019558 & 0.018066 & 0.028284 & 0.352294 & 0.030159 & 0.966886 & 0.919048 & 1.000000 & 1.000000 & 0.279070

# %%
blogs.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#             Nodes       times  pagerank  redPagerank     group    inDegree  \
# mean   667.122449   24.897959  0.005242     0.368015  0.673469   62.204082
# std    338.924379   32.338216  0.009037     0.132603  0.473804   36.609413
# min      0.000000    1.000000  0.000244     0.151416  0.000000    0.000000
# 50%    546.000000    8.000000  0.001986     0.406004  1.000000   61.000000
# max   1214.000000  120.000000  0.045289     0.565289  1.000000  178.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   33.122449             0.700698              0.511324       0.792839
# std    56.840652             0.407337              0.422285       0.301520
# min     0.000000             0.000000              0.000000       0.000000
# 50%    16.000000             0.985075              0.642857       0.931034
# max   287.000000             1.000000              1.000000       1.000000
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean  4.517570e+18     1.734694         0.540551        2.300000
# std   4.658506e+18     2.069375         0.707990        0.456435
# min   2.000000e+00     0.000000         0.000000        2.000000
# 50%   3.000000e+00     2.000000         0.136000        2.000000
# max   9.223372e+18     7.000000         2.333000        3.000000
#
#       NoExistsDistance
# mean         15.244898
# std          16.476664
# min           0.000000
# 50%           7.000000
# max          55.000000

# %%
blogs_top = blogs.loc[blogs['times'] >= 32]
temp = blogs_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((blogs_top.times * blogs_top.group) / sum(blogs_top.times)):.6f}")
# Out:
# 1.048538 & 2.500000 & 4.000000 & 38.769231 & 0.010570 & 0.002295 & 0.045289 & 0.398312 & 0.431412 & 0.565289 & 0.723372 & 0.834951 & 1.000000 & 0.893122

# %%
dblp.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#              Nodes       times  pagerank  redPagerank     group    inDegree  \
# mean   6981.016647   15.453032  0.000234     0.153044  0.147444   19.142687
# std    2860.974881   67.600387  0.000188     0.101888  0.354758   18.709906
# min       5.000000    1.000000  0.000026     0.006216  0.000000    1.000000
# 50%    6968.000000    2.000000  0.000187     0.126355  0.000000   13.000000
# max   13005.000000  718.000000  0.002166     0.601685  1.000000  205.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   19.142687             0.154443              0.154443       0.753306
# std    18.709906             0.125520              0.125520       0.266584
# min     1.000000             0.000000              0.000000       0.000000
# 50%    13.000000             0.142857              0.142857       0.833333
# max   205.000000             0.666667              0.666667       1.000000
#
#       MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean     3.208086     3.608799         3.498027        3.545779
# std      0.828499     0.693760         0.683112        0.716296
# min      2.000000     2.000000         2.000000        2.000000
# 50%      3.000000     4.000000         3.889000        4.000000
# max      4.000000     4.000000         4.000000        4.000000
#
#       NoExistsDistance
# mean               0.0
# std                0.0
# min                0.0
# 50%                0.0
# max                0.0

# %%
dblp_top = dblp.loc[dblp['times'] >= 9]
temp = dblp_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((dblp_top.times * dblp_top.group) / sum(dblp_top.times)):.6f}")
# Out:
# 3.779097 & 3.986726 & 4.000000 & 0.000000 & 0.000476 & 0.000404 & 0.002166 & 0.147623 & 0.128347 & 0.447617 & 0.770683 & 0.834146 & 1.000000 & 0.119201

# %%
twitter.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#              Nodes        times  pagerank  redPagerank     group    inDegree  \
# mean   8973.142523    43.105140  0.000250     0.608257  0.719626   21.065421
# std    5291.087694   210.627379  0.000338     0.163111  0.449708   29.550186
# min       0.000000     1.000000  0.000035     0.176127  0.000000    0.000000
# 50%    8883.000000     2.000000  0.000108     0.639552  1.000000    7.000000
# max   18461.000000  1678.000000  0.003275     0.837937  1.000000  204.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   18.432243             0.670496              0.629914       0.855373
# std    59.461066             0.422388              0.401387       0.226811
# min     0.000000             0.000000              0.000000       0.000000
# 50%     2.000000             1.000000              0.500000       1.000000
# max   785.000000             1.000000              1.000000       1.000000
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean  7.908826e+18     1.053738         0.295119        5.819672
# std   3.228136e+18     2.884897         0.993105        2.059597
# min   2.000000e+00     0.000000         0.000000        2.000000
# 50%   9.223372e+18     0.000000         0.000000        6.000000
# max   9.223372e+18    15.000000         9.000000        9.000000
#
#       NoExistsDistance
# mean         27.964953
# std         126.605164
# min           0.000000
# 50%           2.000000
# max        1032.000000

# %%
twitter_top = twitter.loc[twitter['times'] >= 37]
temp = twitter_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((twitter_top.times * twitter_top.group) / sum(twitter_top.times)):.6f}")
# Out:
# 1.746700 & 6.696429 & 9.333333 & 365.266667 & 0.000873 & 0.000671 & 0.003275 & 0.567982 & 0.662834 & 0.817765 & 0.910210 & 1.000000 & 1.000000 & 0.527677

# %% [markdown]
# # Fair

# %%
books = get_target_nodes_features("books", "fair")
blogs = get_target_nodes_features("blogs", "fair")
dblp = get_target_nodes_features("dblp_course", "fair")
dblp_fair = get_target_nodes_features("dblp_course", "fair")
twitter = get_target_nodes_features("twitter", "fair")

# %%
books.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#           Nodes     times  pagerank  redPagerank     group   inDegree  \
# mean  50.222222  2.500000  0.011711     0.918747  0.972222   8.888889
# std   34.419356  2.299068  0.006092     0.082212  0.166667   5.548631
# min    0.000000  1.000000  0.005531     0.591574  0.000000   3.000000
# 50%   70.500000  1.000000  0.008927     0.952098  1.000000   6.500000
# max   91.000000  7.000000  0.026273     0.973552  1.000000  22.000000
#
#       outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   8.888889             0.948541              0.948541       0.939282
# std    5.548631             0.098344              0.098344       0.134636
# min    3.000000             0.666667              0.666667       0.333333
# 50%    6.500000             1.000000              1.000000       1.000000
# max   22.000000             1.000000              1.000000       1.000000
#
#       MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean     3.027778     3.500000         3.241250        3.194444
# std      0.970600     0.696932         0.785752        0.847499
# min      2.000000     2.000000         2.000000        2.000000
# 50%      3.000000     4.000000         3.000000        3.000000
# max      4.000000     4.000000         4.000000        4.000000
#
#       NoExistsDistance
# mean               0.0
# std                0.0
# min                0.0
# 50%                0.0
# max                0.0

# %%
books_top = books.loc[books['times'] >= 5]
temp = books_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((books_top.times * books_top.group) / sum(books_top.times)):.6f}")
# Out:
# 2.568500 & 2.400000 & 3.300000 & 0.000000 & 0.007763 & 0.007787 & 0.010310 & 0.969345 & 0.969804 & 0.973552 & 1.000000 & 1.000000 & 1.000000 & 1.000000

# %%
blogs.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#            Nodes       times  pagerank  redPagerank  group   inDegree  \
# mean  178.137931   42.068966  0.000272     0.603617    1.0   1.862069
# std   158.940178   54.429464  0.000066     0.016804    0.0   3.215189
# min    12.000000    1.000000  0.000244     0.574350    1.0   0.000000
# 50%   115.000000    3.000000  0.000248     0.600076    1.0   1.000000
# max   615.000000  121.000000  0.000584     0.639208    1.0  13.000000
#
#       outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   9.896552             0.793103              0.999425       0.999425
# std   18.908322             0.250615              0.003095       0.003095
# min    1.000000             0.500000              0.983333       0.983333
# 50%    2.000000             1.000000              1.000000       1.000000
# max   76.000000             1.000000              1.000000       1.000000
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean  2.862426e+18     3.793103         2.118966           4.375
# std   4.342581e+18     2.870780         1.804557           0.958
# min   2.000000e+00     0.000000         0.000000           2.000
# 50%   4.000000e+00     5.000000         2.240000           4.000
# max   9.223372e+18     8.000000         6.000000           6.000
#
#       NoExistsDistance
# mean         19.689655
# std          30.552184
# min           0.000000
# 50%           1.000000
# max         121.000000

# %%
blogs_top = blogs.loc[blogs['times'] >= 114]
temp = blogs_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((blogs_top.times * blogs_top.group) / sum(blogs_top.times)):.6f}")
# Out:
# 2.024625 & 4.285714 & 5.625000 & 57.750000 & 0.000305 & 0.000259 & 0.000584 & 0.622179 & 0.620824 & 0.639208 & 1.000000 & 1.000000 & 1.000000 & 1.000000

# %%
dblp.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#              Nodes       times  pagerank  redPagerank     group    inDegree  \
# mean   6419.792513    8.246193  0.000096     0.332178  0.713198    7.334391
# std    3705.253461   24.154062  0.000106     0.136281  0.452412   10.313830
# min       5.000000    1.000000  0.000019     0.007652  0.000000    1.000000
# 50%    6386.000000    2.000000  0.000068     0.340842  1.000000    4.000000
# max   12997.000000  327.000000  0.002166     0.797311  1.000000  205.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean    7.334391             0.339489              0.339489       0.430180
# std    10.313830             0.283825              0.283825       0.318526
# min     1.000000             0.000000              0.000000       0.000000
# 50%     4.000000             0.307692              0.307692       0.400000
# max   205.000000             1.000000              1.000000       1.000000
#
#       MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean     3.357234     3.769036         3.656760        3.697652
# std      0.779042     0.556593         0.568889        0.589959
# min      2.000000     2.000000         2.000000        2.000000
# 50%      4.000000     4.000000         4.000000        4.000000
# max      4.000000     4.000000         4.000000        4.000000
#
#       NoExistsDistance
# mean               0.0
# std                0.0
# min                0.0
# 50%                0.0
# max                0.0

# %%
dblp_top = dblp.loc[dblp['times'] >= 24]
temp = dblp_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((dblp_top.times * dblp_top.group) / sum(dblp_top.times)):.6f}")
# Out:
# 3.886843 & 4.000000 & 4.000000 & 0.000000 & 0.000094 & 0.000065 & 0.000770 & 0.506018 & 0.511957 & 0.682384 & 0.644511 & 0.600000 & 1.000000 & 0.995308

# %%
twitter.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#              Nodes        times  pagerank  redPagerank     group    inDegree  \
# mean   8901.881449    20.251372  0.000093     0.711314  0.913282    6.177827
# std    5413.434385   107.548392  0.000161     0.093865  0.281576   14.090336
# min       1.000000     1.000000  0.000035     0.348939  0.000000    0.000000
# 50%    9083.000000     1.000000  0.000040     0.734956  1.000000    1.000000
# max   18452.000000  1352.000000  0.002654     1.000000  1.000000  150.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   10.594951             0.706473              0.863470       0.868057
# std    41.453317             0.321914              0.225761       0.218193
# min     0.000000             0.000000              0.000000       0.000000
# 50%     1.000000             0.833333              1.000000       1.000000
# max   785.000000             1.000000              1.000000       1.000000
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean  7.208607e+18     1.789243         0.670958        7.261307
# std   3.813084e+18     3.780740         1.693959        2.801886
# min   2.000000e+00     0.000000         0.000000        2.000000
# 50%   9.223372e+18     0.000000         0.000000        8.000000
# max   9.223372e+18    16.000000        13.000000       13.000000
#
#       NoExistsDistance
# mean         14.509330
# std          73.382182
# min           0.000000
# 50%           1.000000
# max         983.000000

# %%
twitter_top = twitter.loc[twitter['times'] >= 11]
temp = twitter_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((twitter_top.times * twitter_top.group) / sum(twitter_top.times)):.6f}")
# Out:
# 1.975828 & 8.596154 & 9.086022 & 125.387097 & 0.000161 & 0.000078 & 0.001412 & 0.815022 & 0.808553 & 1.000000 & 1.000000 & 1.000000 & 1.000000 & 1.000000

# %% [markdown]
# # Hybrid

# %%
books = get_target_nodes_features("books", "hybrid_node2vec")
blogs = get_target_nodes_features("blogs", "hybrid_node2vec")
dblp = get_target_nodes_features("dblp_course", "hybrid_node2vec")
dblp_h = get_target_nodes_features("dblp_course", "hybrid_node2vec")
twitter = get_target_nodes_features("twitter", "hybrid_node2vec")

# %%
books.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#           Nodes     times  pagerank  redPagerank     group   inDegree  \
# mean  48.363636  2.727273  0.011903     0.916996  0.969697   9.000000
# std   34.545096  1.924720  0.006334     0.085739  0.174078   5.787918
# min    0.000000  1.000000  0.005531     0.591574  0.000000   3.000000
# 50%   70.000000  2.000000  0.008832     0.955357  1.000000   6.000000
# max   91.000000  7.000000  0.026273     0.973552  1.000000  22.000000
#
#       outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   9.000000             0.943863              0.943863       0.933762
# std    5.787918             0.101525              0.101525       0.139461
# min    3.000000             0.666667              0.666667       0.333333
# 50%    6.000000             1.000000              1.000000       1.000000
# max   22.000000             1.000000              1.000000       1.000000
#
#       MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean     2.666667     3.333333         2.981879        2.939394
# std      0.853913     0.692219         0.709005        0.807751
# min      2.000000     2.000000         2.000000        2.000000
# 50%      2.000000     3.000000         3.000000        3.000000
# max      4.000000     4.000000         4.000000        4.000000
#
#       NoExistsDistance
# mean               0.0
# std                0.0
# min                0.0
# 50%                0.0
# max                0.0

# %%
books_top = books.loc[books['times'] >= 4]
temp = books_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((books_top.times * books_top.group) / sum(books_top.times)):.6f}")
# Out:
# 2.445636 & 2.318182 & 3.000000 & 0.000000 & 0.009177 & 0.008084 & 0.016523 & 0.968127 & 0.969590 & 0.973552 & 1.000000 & 1.000000 & 1.000000 & 1.000000

# %%
blogs.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#            Nodes       times  pagerank  redPagerank  group   inDegree  \
# mean  313.222222   33.888889  0.000839     0.564549    1.0  28.916667
# std   163.736218   34.172485  0.000649     0.041893    0.0  29.444742
# min     0.000000    1.000000  0.000244     0.504504    1.0   0.000000
# 50%   342.000000   24.000000  0.000548     0.559754    1.0  21.000000
# max   615.000000  120.000000  0.002627     0.639208    1.0  88.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   31.555556             0.900133              0.971926       0.971926
# std    53.164674             0.199508              0.045447       0.045447
# min     1.000000             0.500000              0.834951       0.834951
# 50%    11.500000             1.000000              1.000000       1.000000
# max   287.000000             1.000000              1.000000       1.000000
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean  1.024819e+18     3.361111         1.524694        2.765625
# std   2.939744e+18     1.742786         0.894345        0.659721
# min   2.000000e+00     0.000000         0.000000        2.000000
# 50%   2.000000e+00     3.500000         1.847500        3.000000
# max   9.223372e+18     6.000000         4.000000        4.000000
#
#       NoExistsDistance
# mean         15.472222
# std          17.830129
# min           0.000000
# 50%          12.500000
# max          80.000000

# %%
blogs_top = blogs.loc[blogs['times'] >= 52]
temp = blogs_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((blogs_top.times * blogs_top.group) / sum(blogs_top.times)):.6f}")
# Out:
# 1.499667 & 2.714286 & 4.000000 & 37.333333 & 0.001275 & 0.001305 & 0.002627 & 0.552998 & 0.551821 & 0.621525 & 0.939249 & 0.952381 & 1.000000 & 1.000000

# %%
dblp.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#              Nodes       times  pagerank  redPagerank     group    inDegree  \
# mean   6562.735007    9.062762  0.000115     0.314419  0.660391    8.981172
# std    3587.824403   36.205588  0.000126     0.142140  0.473742   12.110462
# min       2.000000    1.000000  0.000019     0.007652  0.000000    1.000000
# 50%    6579.500000    1.000000  0.000076     0.318966  1.000000    5.000000
# max   13005.000000  554.000000  0.002166     0.797311  1.000000  205.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean    8.981172             0.299622              0.299622       0.442503
# std    12.110462             0.266189              0.266189       0.328219
# min     1.000000             0.000000              0.000000       0.000000
# 50%     5.000000             0.250000              0.250000       0.400000
# max   205.000000             1.000000              1.000000       1.000000
#
#       MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean     3.317992     3.691771         3.584520        3.622734
# std      0.802559     0.632766         0.632742        0.656918
# min      2.000000     2.000000         2.000000        2.000000
# 50%      4.000000     4.000000         4.000000        4.000000
# max      4.000000     4.000000         4.000000        4.000000
#
#       NoExistsDistance
# mean               0.0
# std                0.0
# min                0.0
# 50%                0.0
# max                0.0

# %%
dblp_top = dblp.loc[dblp['times'] >= 9]
temp = dblp_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((dblp_top.times * dblp_top.group) / sum(dblp_top.times)):.6f}")
# Out:
# 3.835180 & 3.981481 & 4.000000 & 0.000000 & 0.000189 & 0.000148 & 0.000770 & 0.442697 & 0.425074 & 0.706439 & 0.391300 & 0.333333 & 1.000000 & 1.000000

# %%
twitter.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#              Nodes        times  pagerank  redPagerank     group    inDegree  \
# mean   9055.825714    26.355714  0.000136     0.689268  0.885714    9.872857
# std    5325.885292   146.989856  0.000245     0.096703  0.318385   19.763468
# min       2.000000     1.000000  0.000035     0.348939  0.000000    0.000000
# 50%    9009.500000     1.000000  0.000053     0.698361  1.000000    2.000000
# max   18461.000000  1607.000000  0.003275     1.000000  1.000000  204.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   12.255714             0.736977              0.819303       0.827074
# std    47.431439             0.338806              0.245931       0.235482
# min     0.000000             0.000000              0.000000       0.000000
# 50%     1.000000             1.000000              1.000000       1.000000
# max   785.000000             1.000000              1.000000       1.000000
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean  7.378698e+18     1.598571         0.572140        6.910714
# std   3.691987e+18     3.583502         1.504112        2.799838
# min   2.000000e+00     0.000000         0.000000        2.000000
# 50%   9.223372e+18     0.000000         0.000000        7.500000
# max   9.223372e+18    15.000000        12.000000       14.000000
#
#       NoExistsDistance
# mean         18.828571
# std         101.810179
# min           0.000000
# 50%           1.000000
# max        1023.000000

# %%
twitter_top = twitter.loc[twitter['times'] >= 24]
temp = twitter_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((twitter_top.times * twitter_top.group) / sum(twitter_top.times)):.6f}")
# Out:
# 2.234157 & 8.100000 & 9.607843 & 230.450980 & 0.000388 & 0.000241 & 0.002654 & 0.812772 & 0.794099 & 1.000000 & 1.000000 & 1.000000 & 1.000000 & 1.000000

# %% [markdown]
# # Balanced

# %%
books = get_target_nodes_features("books", "dyadic_fair")
blogs = get_target_nodes_features("blogs", "dyadic_fair")
dblp = get_target_nodes_features("dblp_course", "dyadic_fair")
twitter = get_target_nodes_features("twitter", "dyadic_fair")

# %%
books.describe()
# Out:
#            Nodes      times   pagerank  redPagerank      group   inDegree  \
# count  61.000000  61.000000  61.000000    61.000000  61.000000  61.000000
# mean   48.295082   1.475410   0.012240     0.486810   0.475410   9.393443
# std    27.830046   0.744011   0.006006     0.432452   0.503539   5.438378
# min     0.000000   1.000000   0.004968     0.018669   0.000000   3.000000
# 25%    24.000000   1.000000   0.008084     0.029775   0.000000   6.000000
# 50%    50.000000   1.000000   0.010117     0.466240   0.000000   8.000000
# 75%    73.000000   2.000000   0.016242     0.944209   1.000000  13.000000
# max    91.000000   3.000000   0.028284     0.973552   1.000000  24.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# count  61.000000            61.000000             61.000000      61.000000
# mean    9.393443             0.479194              0.479194       0.946407
# std     5.438378             0.468067              0.468067       0.130101
# min     3.000000             0.000000              0.000000       0.333333
# 25%     6.000000             0.000000              0.000000       1.000000
# 50%     8.000000             0.500000              0.500000       1.000000
# 75%    13.000000             1.000000              1.000000       1.000000
# max    24.000000             1.000000              1.000000       1.000000
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# count    61.000000    61.000000        61.000000       61.000000
# mean      3.803279     3.852459         3.827869        3.827869
# std       0.400819     0.357588         0.363837        0.363837
# min       3.000000     3.000000         3.000000        3.000000
# 25%       4.000000     4.000000         4.000000        4.000000
# 50%       4.000000     4.000000         4.000000        4.000000
# 75%       4.000000     4.000000         4.000000        4.000000
# max       4.000000     4.000000         4.000000        4.000000
#
#        NoExistsDistance
# count              61.0
# mean                0.0
# std                 0.0
# min                 0.0
# 25%                 0.0
# 50%                 0.0
# 75%                 0.0
# max                 0.0

# %%
books_top = books.loc[books["times"] >= 2]
temp = books_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((books_top.times * books_top.group) / sum(books_top.times)):.6f}")
# Out:
# 3.825000 & 3.825000 & 3.900000 & 0.000000 & 0.012906 & 0.010509 & 0.028284 & 0.233525 & 0.056736 & 0.772748 & 0.875714 & 1.000000 & 1.000000 & 0.122449

# %%
blogs.describe()
# Out:
#             Nodes      times   pagerank  redPagerank      group   inDegree  \
# count   47.000000  47.000000  47.000000    47.000000  47.000000  47.000000
# mean   297.553191  25.957447   0.000267     0.423853   0.617021   1.319149
# std    250.959187  26.383425   0.000059     0.231049   0.491369   2.638399
# min     12.000000   1.000000   0.000244     0.109263   0.000000   0.000000
# 25%     92.500000   1.000000   0.000244     0.137264   0.000000   0.000000
# 50%    217.000000  10.000000   0.000244     0.589539   1.000000   0.000000
# 75%    461.500000  55.000000   0.000258     0.605719   1.000000   1.500000
# max    910.000000  62.000000   0.000584     0.639208   1.000000  13.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# count  47.000000            47.000000             47.000000      47.000000
# mean    6.617021             0.617021              0.616667       0.999645
# std    15.364489             0.333179              0.491092       0.002431
# min     1.000000             0.000000              0.000000       0.983333
# 25%     1.000000             0.500000              0.000000       1.000000
# 50%     1.000000             0.500000              1.000000       1.000000
# 75%     2.000000             1.000000              1.000000       1.000000
# max    76.000000             1.000000              1.000000       1.000000
#
#         MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# count  4.700000e+01    47.000000        47.000000       26.000000
# mean   4.121081e+18     2.914894         1.547447        4.442308
# std    4.635090e+18     2.819419         1.954632        0.668235
# min    2.000000e+00     0.000000         0.000000        4.000000
# 25%    4.000000e+00     0.000000         0.000000        4.000000
# 50%    5.000000e+00     4.000000         0.068000        4.000000
# 75%    9.223372e+18     5.000000         3.379500        5.000000
# max    9.223372e+18     8.000000         6.000000        6.000000
#
#        NoExistsDistance
# count         47.000000
# mean          16.297872
# std           22.096542
# min            0.000000
# 25%            1.000000
# 50%            6.000000
# 75%           14.000000
# max           62.000000

# %%
blogs_top = blogs.loc[blogs["times"] >= 55]
temp = blogs_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((blogs_top.times * blogs_top.group) / sum(blogs_top.times)):.6f}")
# Out:
# 1.896615 & 4.300000 & 4.384615 & 32.923077 & 0.000284 & 0.000251 & 0.000584 & 0.435071 & 0.615364 & 0.639208 & 1.000000 & 1.000000 & 1.000000 & 0.614173

# %%
blogs_top.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#            Nodes      times  pagerank  redPagerank     group   inDegree  \
# mean  384.461538  58.615385  0.000284     0.435071  0.615385   2.000000
# std   305.082124   2.256046  0.000093     0.246416  0.506370   3.488075
# min    54.000000  55.000000  0.000244     0.132363  0.000000   0.000000
# 50%   332.000000  59.000000  0.000251     0.615364  1.000000   1.000000
# max   910.000000  62.000000  0.000584     0.639208  1.000000  13.000000
#
#       outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   1.230769             0.538462              0.615385            1.0
# std    0.438529             0.431158              0.506370            0.0
# min    1.000000             0.000000              0.000000            1.0
# 50%    1.000000             0.500000              1.000000            1.0
# max    2.000000             1.000000              1.000000            1.0
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean  2.128470e+18     4.384615         1.896615        4.300000
# std   4.044716e+18     2.873397         1.817750        0.674949
# min   2.000000e+00     0.000000         0.000000        4.000000
# 50%   4.000000e+00     5.000000         3.089000        4.000000
# max   9.223372e+18     8.000000         4.255000        6.000000
#
#       NoExistsDistance
# mean         32.923077
# std          25.078083
# min           8.000000
# 50%          14.000000
# max          62.000000

# %%
dblp.describe()
# Out:
#               Nodes        times     pagerank  redPagerank        group  \
# count   2722.000000  2722.000000  2722.000000  2722.000000  2722.000000
# mean    6619.372153     4.774431     0.000091     0.191442     0.360397
# std     3731.213528    12.978419     0.000085     0.171816     0.480204
# min        5.000000     1.000000     0.000019     0.003426     0.000000
# 25%     3348.750000     1.000000     0.000051     0.047460     0.000000
# 50%     6715.000000     2.000000     0.000069     0.098112     0.000000
# 75%     9861.500000     3.000000     0.000097     0.344811     1.000000
# max    12997.000000   228.000000     0.001032     0.730027     1.000000
#
#           inDegree    outDegree  redNeighborsInRatio  redNeighborsOutRatio  \
# count  2722.000000  2722.000000          2722.000000           2722.000000
# mean      6.867010     6.867010             0.172938              0.172938
# std       8.343504     8.343504             0.257996              0.257996
# min       1.000000     1.000000             0.000000              0.000000
# 25%       3.000000     3.000000             0.000000              0.000000
# 50%       4.000000     4.000000             0.000000              0.000000
# 75%       8.000000     8.000000             0.312500              0.312500
# max     117.000000   117.000000             1.000000              1.000000
#
#        out_homophily  MinDistance  MaxDistance  AverageDistance  \
# count    2722.000000  2722.000000  2722.000000      2722.000000
# mean        0.720301     3.634093     3.841293         3.780159
# std         0.353582     0.622840     0.453432         0.473701
# min         0.000000     2.000000     2.000000         2.000000
# 25%         0.400000     3.000000     4.000000         3.875000
# 50%         1.000000     4.000000     4.000000         4.000000
# 75%         1.000000     4.000000     4.000000         4.000000
# max         1.000000     4.000000     4.000000         4.000000
#
#        MedianDistance  NoExistsDistance
# count     2722.000000            2722.0
# mean         3.801616               0.0
# std          0.480556               0.0
# min          2.000000               0.0
# 25%          4.000000               0.0
# 50%          4.000000               0.0
# 75%          4.000000               0.0
# max          4.000000               0.0

# %%
dblp_top = dblp.loc[dblp["times"] > 7]
temp = dblp_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((dblp_top.times * dblp_top.group) / sum(dblp_top.times)):.6f}")
# Out:
# 3.922380 & 4.000000 & 4.000000 & 0.000000 & 0.000103 & 0.000075 & 0.000770 & 0.321801 & 0.431565 & 0.706439 & 0.739119 & 0.750000 & 1.000000 & 0.763812

# %%
dblp_top.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#              Nodes       times  pagerank  redPagerank     group   inDegree  \
# mean   6355.199377   25.205607  0.000103     0.321801  0.635514   7.663551
# std    3626.466219   30.658728  0.000097     0.228817  0.482037   8.417553
# min      31.000000    8.000000  0.000019     0.009049  0.000000   1.000000
# 50%    6394.000000   15.000000  0.000075     0.431565  1.000000   5.000000
# max   12856.000000  228.000000  0.000770     0.706439  1.000000  61.000000
#
#       outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   7.663551             0.389003              0.389003       0.739119
# std    8.417553             0.347387              0.347387       0.275100
# min    1.000000             0.000000              0.000000       0.000000
# 50%    5.000000             0.400000              0.400000       0.750000
# max   61.000000             1.000000              1.000000       1.000000
#
#       MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean     3.345794          4.0         3.922380             4.0
# std      0.638888          0.0         0.101026             0.0
# min      2.000000          4.0         3.524000             4.0
# 50%      3.000000          4.0         3.950000             4.0
# max      4.000000          4.0         4.000000             4.0
#
#       NoExistsDistance
# mean               0.0
# std                0.0
# min                0.0
# 50%                0.0
# max                0.0

# %%
twitter.describe()
# Out:
#               Nodes        times     pagerank  redPagerank        group  \
# count   1463.000000  1463.000000  1463.000000  1463.000000  1463.000000
# mean    9272.104580    12.610390     0.000103     0.522286     0.507861
# std     5410.791478    49.758087     0.000167     0.189979     0.500109
# min        1.000000     1.000000     0.000035     0.149708     0.000000
# 25%     4510.000000     1.000000     0.000036     0.336549     0.000000
# 50%     9217.000000     2.000000     0.000043     0.602443     1.000000
# 75%    14090.500000     5.000000     0.000087     0.639552     1.000000
# max    18465.000000   709.000000     0.002654     1.000000     1.000000
#
#           inDegree    outDegree  redNeighborsInRatio  redNeighborsOutRatio  \
# count  1463.000000  1463.000000          1463.000000           1463.000000
# mean      7.820916    11.482570             0.532480              0.412112
# std      15.879356    39.531865             0.411113              0.381218
# min       0.000000     0.000000             0.000000              0.000000
# 25%       1.000000     0.000000             0.023306              0.000000
# 50%       2.000000     1.000000             0.500000              0.500000
# 75%       7.000000     5.000000             1.000000              0.500000
# max     150.000000   785.000000             1.000000              1.000000
#
#        out_homophily   MinDistance  MaxDistance  AverageDistance  \
# count    1463.000000  1.463000e+03  1463.000000      1463.000000
# mean        0.807724  7.035737e+18     2.124402         0.831466
# std         0.241450  3.924558e+18     3.954543         1.941218
# min         0.000000  2.000000e+00     0.000000         0.000000
# 25%         0.500000  9.223372e+18     0.000000         0.000000
# 50%         1.000000  9.223372e+18     0.000000         0.000000
# 75%         1.000000  9.223372e+18     0.000000         0.000000
# max         1.000000  9.223372e+18    16.000000        13.000000
#
#        MedianDistance  NoExistsDistance
# count      347.000000       1463.000000
# mean         8.021614          8.693096
# std          1.670111         32.955378
# min          2.000000          0.000000
# 25%          7.000000          1.000000
# 50%          8.000000          1.000000
# 75%          9.000000          4.000000
# max         13.000000        621.000000

# %%
twitter_top = twitter.loc[twitter["times"] >= 11]
temp = twitter_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((twitter_top.times * twitter_top.group) / sum(twitter_top.times)):.6f}")
# Out:
# 2.301828 & 8.097561 & 8.390625 & 52.802083 & 0.000186 & 0.000076 & 0.001822 & 0.461351 & 0.324677 & 1.000000 & 0.975451 & 1.000000 & 1.000000 & 0.430407

# %%
twitter_top.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#              Nodes       times  pagerank  redPagerank     group    inDegree  \
# mean   9166.057292   81.088542  0.000186     0.461351  0.333333   15.953125
# std    5421.470963  116.185524  0.000259     0.258634  0.472637   24.450246
# min      10.000000   11.000000  0.000035     0.149708  0.000000    0.000000
# 50%    9067.000000   33.000000  0.000076     0.324677  0.000000    5.000000
# max   18465.000000  709.000000  0.001822     1.000000  1.000000  137.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean    7.145833             0.372754              0.330104       0.975451
# std    19.867350             0.410515              0.459455       0.113475
# min     0.000000             0.000000              0.000000       0.000000
# 50%     1.000000             0.118055              0.000000       1.000000
# max   145.000000             1.000000              1.000000       1.000000
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean  1.345075e+18     8.390625         2.301828        8.097561
# std   3.263799e+18     4.034993         1.866008        1.486006
# min   3.000000e+00     0.000000         0.000000        4.000000
# 50%   7.000000e+00     9.000000         2.094500        8.000000
# max   9.223372e+18    16.000000         7.433000       12.000000
#
#       NoExistsDistance
# mean         52.802083
# std          77.722169
# min           4.000000
# 50%          23.500000
# max         621.000000

# %% [markdown]
# # Hybrid Balanced.

# %%
books = get_target_nodes_features("books", "hybrid_balanced_node2vec")
blogs = get_target_nodes_features("blogs", "hybrid_balanced_node2vec")
dblp = get_target_nodes_features("dblp_course", "hybrid_balanced_node2vec")
twitter = get_target_nodes_features("twitter", "hybrid_balanced_node2vec")

# %%
books.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#           Nodes     times  pagerank  redPagerank     group   inDegree  \
# mean  52.585366  2.195122  0.014719     0.485332  0.463415  11.365854
# std   26.525436  1.100443  0.007033     0.412346  0.504854   6.374779
# min    1.000000  1.000000  0.004968     0.019940  0.000000   3.000000
# 50%   52.000000  2.000000  0.014335     0.466240  0.000000  10.000000
# max   91.000000  4.000000  0.028284     0.970356  1.000000  24.000000
#
#       outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean  11.365854             0.469045              0.469045       0.920264
# std    6.374779             0.450897              0.450897       0.152488
# min    3.000000             0.000000              0.000000       0.333333
# 50%   10.000000             0.500000              0.500000       1.000000
# max   24.000000             1.000000              1.000000       1.000000
#
#       MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean     3.268293     3.853659         3.603659        3.658537
# std      0.671729     0.357839         0.404745        0.439304
# min      2.000000     3.000000         3.000000        3.000000
# 50%      3.000000     4.000000         3.750000        4.000000
# max      4.000000     4.000000         4.000000        4.000000
#
#       NoExistsDistance
# mean               0.0
# std                0.0
# min                0.0
# 50%                0.0
# max                0.0

# %%
books_top = books.loc[books["times"] >= 3]
temp = books_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((books_top.times * books_top.group) / sum(books_top.times)):.6f}")
# Out:
# 3.659091 & 3.863636 & 4.000000 & 0.000000 & 0.020819 & 0.020224 & 0.028284 & 0.119366 & 0.030159 & 0.917100 & 0.993939 & 1.000000 & 1.000000 & 0.071429

# %%
blogs.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#             Nodes      times  pagerank  redPagerank     group    inDegree  \
# mean   578.706897  21.034483  0.002499     0.359640  0.500000   43.517241
# std    307.797895  20.489591  0.005518     0.199118  0.504367   37.956689
# min      0.000000   1.000000  0.000244     0.128545  0.000000    0.000000
# 50%    561.500000  13.000000  0.001303     0.372818  0.500000   35.000000
# max   1212.000000  62.000000  0.039050     0.621525  1.000000  178.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   44.482759             0.628432              0.488783       0.979816
# std    56.656317             0.381027              0.485259       0.036642
# min     1.000000             0.000000              0.000000       0.834951
# 50%    28.000000             0.688041              0.451958       1.000000
# max   287.000000             1.000000              1.000000       1.000000
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean  3.816568e+18     2.034483         1.054155        2.676471
# std   4.582299e+18     2.034488         1.206297        0.588814
# min   2.000000e+00     0.000000         0.000000        2.000000
# 50%   3.000000e+00     2.000000         0.109500        3.000000
# max   9.223372e+18     6.000000         4.000000        4.000000
#
#       NoExistsDistance
# mean         13.034483
# std          15.037923
# min           0.000000
# 50%          10.000000
# max          54.000000

# %%
blogs_top = blogs.loc[blogs["times"] >= 37]
temp = blogs_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((blogs_top.times * blogs_top.group) / sum(blogs_top.times)):.6f}")
# Out:
# 1.284800 & 2.769231 & 3.600000 & 27.400000 & 0.002025 & 0.001377 & 0.006449 & 0.358408 & 0.505282 & 0.565289 & 0.953308 & 0.969697 & 1.000000 & 0.570505

# %%
dblp.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#              Nodes       times  pagerank  redPagerank     group    inDegree  \
# mean   6884.400814    7.560209  0.000156     0.206821  0.380454   12.440372
# std    3267.350154   25.160712  0.000150     0.159633  0.485640   14.721624
# min       2.000000    1.000000  0.000022     0.003426  0.000000    1.000000
# 50%    6881.000000    2.000000  0.000109     0.152665  0.000000    8.000000
# max   13005.000000  383.000000  0.002166     0.706439  1.000000  205.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   12.440372             0.178832              0.178832       0.652506
# std    14.721624             0.211089              0.211089       0.352840
# min     1.000000             0.000000              0.000000       0.000000
# 50%     8.000000             0.122449              0.122449       0.800000
# max   205.000000             1.000000              1.000000       1.000000
#
#       MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean     3.450262     3.757417         3.673721        3.707388
# std      0.720358     0.555344         0.562106        0.576669
# min      2.000000     2.000000         2.000000        2.000000
# 50%      4.000000     4.000000         4.000000        4.000000
# max      4.000000     4.000000         4.000000        4.000000
#
#       NoExistsDistance
# mean               0.0
# std                0.0
# min                0.0
# 50%                0.0
# max                0.0

# %%
dblp_top = dblp.loc[dblp["times"] > 11]
temp = dblp_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((dblp_top.times * dblp_top.group) / sum(dblp_top.times)):.6f}")
# Out:
# 3.865278 & 4.000000 & 4.000000 & 0.000000 & 0.000261 & 0.000212 & 0.001032 & 0.272132 & 0.336892 & 0.682384 & 0.616482 & 0.600000 & 1.000000 & 0.691926

# %%
twitter.describe().iloc[[1, 2, 3, 5, 7]]
# Out:
#              Nodes       times  pagerank  redPagerank     group    inDegree  \
# mean   9265.300664   15.323090  0.000138     0.551941  0.602159   11.098007
# std    5388.036480   66.664888  0.000213     0.164139  0.489656   20.046339
# min       8.000000    1.000000  0.000035     0.149708  0.000000    0.000000
# 50%    9250.500000    1.000000  0.000047     0.639552  1.000000    2.000000
# max   18465.000000  709.000000  0.002654     1.000000  1.000000  150.000000
#
#        outDegree  redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# mean   12.608804             0.605886              0.442391       0.729517
# std    44.454398             0.433296              0.331982       0.246600
# min     0.000000             0.000000              0.000000       0.000000
# 50%     1.000000             0.914216              0.500000       0.620193
# max   785.000000             1.000000              1.000000       1.000000
#
#        MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# mean  7.216293e+18     1.871262         0.753255        7.646947
# std   3.807323e+18     3.704039         1.900490        1.698086
# min   2.000000e+00     0.000000         0.000000        2.000000
# 50%   9.223372e+18     0.000000         0.000000        8.000000
# max   9.223372e+18    15.000000        13.000000       14.000000
#
#       NoExistsDistance
# mean         10.494186
# std          43.513950
# min           0.000000
# 50%           1.000000
# max         621.000000

# %%
twitter_top = twitter.loc[twitter["times"] >= 10]
temp = twitter_top.describe().iloc[[1, 2, 3, 5, 7]]
print(f"{temp.AverageDistance['mean']:.6f} & {temp.MedianDistance['mean']:.6f} & {temp.MaxDistance['mean']:.6f} & {temp.NoExistsDistance['mean']:.6f}\
 & {temp['pagerank']['mean']:.6f} & {temp['pagerank']['50%']:.6f} & {temp['pagerank']['max']:.6f}\
 & {temp['redPagerank']['mean']:.6f} & {temp['redPagerank']['50%']:.6f} & {temp['redPagerank']['max']:.6f}\
 & {temp['out_homophily']['mean']:.6f} & {temp['out_homophily']['50%']:.6f} & {temp['out_homophily']['max']:.6f}\
 & {sum((twitter_top.times * twitter_top.group) / sum(twitter_top.times)):.6f}")
# Out:
# 2.268079 & 7.809353 & 8.042683 & 65.567073 & 0.000353 & 0.000240 & 0.002654 & 0.484619 & 0.357163 & 1.000000 & 0.975267 & 1.000000 & 1.000000 & 0.421515

# %%
twitter_top
# Out:
#      Nodes  times  pagerank  redPagerank  group  inDegree  outDegree  \
# 3     1320    709  0.000671     0.176127      0        70          1
# 19    4826    670  0.000766     0.817765      1        92          1
# 11    6452    663  0.001822     0.207209      0       102          5
# 2    16720    621  0.000298     1.000000      1         5          1
# 15   17325    598  0.000577     0.286950      0        71          1
# ..     ...    ...       ...          ...    ...       ...        ...
# 242   5455     10  0.000759     0.348784      0       112         84
# 230  15440     10  0.000344     0.728516      1        41          7
# 332   6548     10  0.000086     0.335146      0         8          2
# 212   6813     10  0.000075     0.304402      0         9          1
# 25   14880     10  0.000850     0.351236      0        51        109
#
#      redNeighborsInRatio  redNeighborsOutRatio  out_homophily  \
# 3               0.014286              0.000000       1.000000
# 19              0.967391              1.000000       1.000000
# 11              0.019608              0.000000       1.000000
# 2               0.600000              1.000000       1.000000
# 15              0.014085              0.000000       1.000000
# ..                   ...                   ...            ...
# 242             0.017857              0.011905       0.988095
# 230             0.878049              1.000000       1.000000
# 332             0.250000              0.000000       1.000000
# 212             0.111111              0.000000       1.000000
# 25              0.000000              0.009174       0.990826
#
#              MinDistance  MaxDistance  AverageDistance  MedianDistance  \
# 3                      3           10            2.329             7.0
# 19                     7           15            5.157            10.0
# 11                     2            9            2.157             6.0
# 2    9223372036854775807            0            0.000             NaN
# 15                     7           13            2.532            10.0
# ..                   ...          ...              ...             ...
# 242                    6            6            0.600             6.0
# 230  9223372036854775807            0            0.000             NaN
# 332  9223372036854775807            0            0.000             NaN
# 212  9223372036854775807            0            0.000             NaN
# 25   9223372036854775807            0            0.000             NaN
#
#      NoExistsDistance
# 3                 471
# 19                330
# 11                423
# 2                 621
# 15                439
# ..                ...
# 242                 9
# 230                10
# 332                10
# 212                10
# 25                 10
#
# [164 rows x 15 columns]

# %% [markdown]
# # Names

# %%
dblp_names.head()
# Out:
#    Node_id         Author_Name
# 0        0  Frank Hing-Wah Luk
# 1        1       David Nilsson
# 2        2     Emelie Kullmann
# 3        3     Gabriel Isheden
# 4        4       Martin Bohman

# %%
dblp_names = pd.read_csv("dblp_course/names.txt", sep="\t")
dblp_n2v_top = dblp_n2v.head(20).join(dblp_names.set_index("Node_id"), on="Nodes")[["Author_Name", "times"]]
dblp_fair_top = dblp_fair.head(20).join(dblp_names.set_index("Node_id"), on="Nodes")[["Author_Name", "times"]]
dblp_h_top = dblp_h.head(20).join(dblp_names.set_index("Node_id"), on="Nodes")[["Author_Name", "times"]]
dblp_b_top = dblp_b.head(20).join(dblp_names.set_index("Node_id"), on="Nodes")[["Author_Name", "times"]]
dblp_hb_top = dblp_hb.head(20).join(dblp_names.set_index("Node_id"), on="Nodes")[["Author_Name", "times"]]

# %%
print("\\hline")
print("Node2vec & Fair & Hybrid n2v & Balanced & Hybrid bal. n2v")
print("\\hline")
values = list()
for n, f, h, b, hb in zip(dblp_n2v_top.iterrows(), dblp_fair_top.iterrows(), dblp_h_top.iterrows(), dblp_b_top.iterrows(), dblp_hb_top.iterrows()):
    temp_value = n[1].Author_Name + " (" + str(n[1].times) + ") & "
    temp_value += f[1].Author_Name + " (" + str(f[1].times) + ") & "    
    temp_value += h[1].Author_Name + " (" + str(h[1].times) + ") & "    
    temp_value += b[1].Author_Name + " (" + str(b[1].times) + ") & "    
    temp_value += hb[1].Author_Name + " (" + str(hb[1].times) + ") "
    values.append(temp_value)

for row in values:
    print(row + "\\\\")
    print("\\hline")
# Out:
# \hline
# Node2vec & Fair & Hybrid n2v & Balanced & Hybrid bal. n2v
# \hline
# Douglas W. Oard (718) & Elena Ferrari (327) & Elke A. Rundensteiner (554) & Elena Ferrari (228) & Elke A. Rundensteiner (383) \\
# \hline
# Wolfgang Lehner (638) & Barbara Carminati (277) & Elena Baralis (497) & Elena Baralis (190) & Elena Baralis (354) \\
# \hline
# Karl Aberer (610) & Elena Baralis (274) & Ana Paula Appel (372) & Barbara Carminati (185) & Ana Paula Appel (257) \\
# \hline
# Maarten de Rijke (597) & Bahar Ghadiri Bashardoost (252) & Elena Ferrari (347) & Bahar Ghadiri Bashardoost (168) & Elena Ferrari (241) \\
# \hline
# Clement T. Yu (588) & Kelly Lyons (239) & Elisa Bertino (311) & Marina Buzzi (159) & Elisa Bertino (236) \\
# \hline
# Volker Markl (536) & Marina Buzzi (228) & Lois M. L. Delcambre (299) & Kelly Lyons (157) & Isabel F. Cruz (211) \\
# \hline
# Amit P. Sheth (529) & Christina Christodoulakis (217) & Silvana Castano (298) & Christina Christodoulakis (151) & Shashi Shekhar (205) \\
# \hline
# Martin Ester (487) & Barbara Leporini (210) & Shashi Shekhar (294) & Barbara Leporini (148) & Lois M. L. Delcambre (205) \\
# \hline
# Filippo Menczer (444) & Stacia De Lima (198) & Barbara Carminati (277) & Bruna D. Andrade (129) & Silvana Castano (199) \\
# \hline
# Foster J. Provost (401) & Bruna D. Andrade (187) & Sonia Bergamaschi (277) & Stacia De Lima (129) & Bernhard Seeger (199) \\
# \hline
# Lise Getoor (400) & Beatriz S. R. de Souza (184) & Isabel F. Cruz (275) & Beatriz S. R. de Souza (128) & Barbara Carminati (185) \\
# \hline
# Elke A. Rundensteiner (356) & Silvana Castano (171) & Claudia Plant (218) & Silvana Castano (120) & Sonia Bergamaschi (176) \\
# \hline
# Alfons Kemper (327) & Nihal Dindar (163) & Barbara Leporini (210) & Nihal Dindar (103) & Claudia Plant (164) \\
# \hline
# Panos K. Chrysanthis (250) & Karen Works (123) & Barbara Catania (194) & Silvia Chiusano (85) & Barbara Leporini (139) \\
# \hline
# Hannu Toivonen (206) & Silvia Chiusano (112) & Melanie Herschel (184) & Tania Cerquitelli (85) & Hasso Plattner (134) \\
# \hline
# Noriko Kando (183) & Tania Cerquitelli (112) & Angela Bonifati (181) & Karen Works (84) & Tova Milo (128) \\
# \hline
# Theo Harder (165) & Andrea Bianco (105) & Christina Christodoulakis (168) & Andrea Bianco (81) & Barbara Catania (127) \\
# \hline
# Bhavani M. Thuraisingham (162) & Ana Maria Heuminski de Avila (96) & Tova Milo (164) & Ana Maria Heuminski de Avila (73) & Michael R. Berthold (126) \\
# \hline
# Felix Naumann (144) & Kavita Ganesan (91) & Bhavani M. Thuraisingham (148) & Kavita Ganesan (68) & Steve Lawrence (125) \\
# \hline
# Ophir Frieder (137) & Luciana A. S. Romani (89) & Noriko Kando (147) & Luciana A. S. Romani (65) & Angela Bonifati (125) \\
# \hline

# %%
for index, row in dblp_h_top.iterrows():
    print(row.Author_Name + str(row.times))
# Out:
# Elke A. Rundensteiner554
# Elena Baralis497
# Ana Paula Appel372
# Elena Ferrari347
# Elisa Bertino311
# Lois M. L. Delcambre299
# Silvana Castano298
# Shashi Shekhar294
# Barbara Carminati277
# Sonia Bergamaschi277
# Isabel F. Cruz275
# Claudia Plant218
# Barbara Leporini210
# Barbara Catania194
# Melanie Herschel184
# Angela Bonifati181
# Christina Christodoulakis168
# Tova Milo164
# Bhavani M. Thuraisingham148
# Noriko Kando147
