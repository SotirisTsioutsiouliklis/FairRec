# %% [markdown]
# ### Sources and Targets.

# %%
# Import needed libraries.
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Analyze Source nodes.
df = pd.read_csv('source_node_infos.txt', sep= '\t')
df = df[(df[['smax_impact']] != 0).all(axis=1)]

# %%
#df.head(50)

# %%
pd.plotting.scatter_matrix(df);
# Out:
# <img src="data:image/png;base64,..." width="1019">

# %%
# Analyze Target nodes.
df = pd.read_csv('target_s_62_node_infos.txt', sep= '\t')
df = df[(df[['t_Impact']] != 0).all(axis=1)]

# %%
df.head()
# Out:
#    Node  Pagerank  Src_Personilized  Red_Personilized  Out_Degree  \
# 0     0  0.005531          0.000577          0.969433           3
# 1     1  0.007490          0.000988          0.967858           5
# 2     2  0.014982          0.002946          0.959730          12
# 3     3  0.015440          0.003140          0.959087          12
# 4     4  0.006981          0.001253          0.955506           5
#
#    Out_Red_Degree  t_Impact
# 0               3  0.005137
# 1               5  0.005128
# 2              12  0.005077
# 3              12  0.005072
# 4               5  0.005050

# %%
pd.plotting.scatter_matrix(df)
# Out:
# <img src="data:image/png;base64,..." width="999">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A2F0984DC8>,
# ...
#       dtype=object)

# %%
# Analyze Target nodes.
df = pd.read_csv('target_s_24_node_infos.txt', sep= '\t')
df = df[(df[['t_Impact']] != 0).all(axis=1)]

# %%
pd.plotting.scatter_matrix(df);
# Out:
# <img src="data:image/png;base64,..." width="975">

# %%
# Analyze Target nodes.
df = pd.read_csv('target_s_39_node_infos.txt', sep= '\t')
df = df[(df[['t_Impact']] != 0).all(axis=1)]

# %%
pd.plotting.scatter_matrix(df);
# Out:
# <img src="data:image/png;base64,..." width="977">
