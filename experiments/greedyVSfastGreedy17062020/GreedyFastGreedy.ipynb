# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the source nodes.
sourceNodes = []
with open('randomSourceNodes.txt', 'r') as fileOne:
    for line in fileOne:
        sourceNodes.append(int(line))

# %%
sourceNodes
# Out:
# [10940, 18369, 18451, 19516, 28884, 14884, 3715, 3479, 8470, 252]

# %%
# Plot the Fairness for each Source Node.
plt.figure()
for node in range(9):
    greedyRed = []
    fastGreedyRed = []
    with open('%dRedPagerankGreedy.txt' %sourceNodes[node], 'r') as fileOne:
        for line in fileOne:
            greedyRed.append(float(line))
    with open('%dRedPagerankFastGreedy.txt' %sourceNodes[node], 'r') as fileOne:
        for line in fileOne:
            fastGreedyRed.append(float(line))
    
    plt.subplot(330 + node + 1)
    plt.plot(np.arange(len(greedyRed)),np.array(greedyRed), '-.b')
    plt.plot(np.arange(len(fastGreedyRed)),np.array(fastGreedyRed), '-.r')
# Out:
# <img src="data:image/png;base64,..." width="990">

# %%
# Compare edges selected.
for node in range(10):
    greedyRed = []
    fastGreedyRed = []
    with open('%dedgesGreedy.txt' %sourceNodes[node], 'r') as fileOne:
        fileOne.readline()
        for line in fileOne:
            greedyRed.append(float(line.split()[1]))
    with open('%dedgesFastGreedy.txt' %sourceNodes[node], 'r') as fileOne:
        fileOne.readline()
        for line in fileOne:
            fastGreedyRed.append(float(line.split()[1]))
    isIdentical = True
    for i in range(len(greedyRed)):
        if greedyRed[i] != fastGreedyRed[i]:
            isIdentical = False
            print(node, i)
            break
    if isIdentical:
        print(node, " Is Identical")
# Out:
# 0  Is Identical
# 1  Is Identical
# 2  Is Identical
# 3 21
# 4  Is Identical
# 5  Is Identical
# 6 22
# 7  Is Identical
# 8  Is Identical
# 9 21

# %%
greedyRed[20:23]
# Out:
# [33.0, 24720.0, 25650.0]

# %%
fastGreedyRed[20:23]
# Out:
# [33.0, 25650.0, 24720.0]

# %%
print(greedyRed[0:30])
# Out:
# [9925.0, 29514.0, 7650.0, 29667.0, 838.0, 26168.0, 26546.0, 29138.0, 2868.0, 28795.0, 24962.0, 28858.0, 7642.0, 1362.0, 2800.0, 1472.0, 27796.0, 27024.0, 14019.0, 4.0, 33.0, 24720.0, 25650.0, 27950.0, 23920.0, 2335.0, 1415.0, 26528.0, 30089.0, 2991.0]

# %%
print(fastGreedyRed[0:30])
# Out:
# [9925.0, 29514.0, 7650.0, 29667.0, 838.0, 26168.0, 26546.0, 29138.0, 2868.0, 28795.0, 24962.0, 28858.0, 7642.0, 1362.0, 2800.0, 1472.0, 27796.0, 27024.0, 14019.0, 4.0, 33.0, 25650.0, 24720.0, 27950.0, 23920.0, 2335.0, 1415.0, 26528.0, 30089.0, 2991.0]
