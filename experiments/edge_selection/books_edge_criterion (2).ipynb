# %%
# Import libraries.
# %matplotlib notebook
import pandas as pd

# %%
# Load data.
#grd_10_30 = pd.read_csv('out_greedy_all.txt', sep='\t', usecols=[0, 1], header=0, names=['Edge', 'Greedy'])
rnd = pd.read_csv('out_random_edges_all.txt', sep='\t', usecols=[0, 1], header=0, names=['Edge', 'Random'])
one = pd.read_csv('out_one_edges_all.txt', sep='\t', usecols=[0, 1], header=0, names=['Edge', 'Criterion_product'])
two = pd.read_csv('out_two_edges_all.txt', sep='\t', usecols=[0, 1], header=0, names=['Edge', 'Criterion_sum'])
three = pd.read_csv('out_three_edges_all.txt', sep='\t', usecols=[0, 1], header=0, names=['Edge', 'Criterion_formula'])
four = pd.read_csv('out_three_greedy_edges_all.txt', sep='\t', usecols=[0, 1], header=0, names=['Edge', 'Criterion_greedy_formula'])

#one.head()

# %%
grd_6_50 = pd.read_csv('out_greedy_all.txt', sep='\t', usecols=[0, 1], header=0, names=['Edge', 'Greedy2'])

# %%
grd_15_20 = pd.read_csv('out_greedy_all.txt', sep='\t', usecols=[0, 1], header=0, names=['Edge', 'Greedy3'])

# %%
grd_20_15 = pd.read_csv('out_greedy_all.txt', sep='\t', usecols=[0, 1], header=0, names=['Edge', 'Greedy4'])

# %%
# Join data.
#df = pd.merge(grd_10_30, rnd, how='right', on='Edge')
df = pd.merge(rnd, one, how='right', on='Edge')
df = df.merge(two, how='right', on='Edge')
df = df.merge(three, how='right', on='Edge')
df = df.merge(four, how='right', on='Edge')

#df = df.merge(grd_5_60, how='right', on='Edge')
#df = df.merge(grd_15_20, how='right', on='Edge')
#df = df.merge(grd_20_15, how='right', on='Edge')
#df.head()

# %%
# Plot.
df.plot(x =0, y=[1,2,3,4,5])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Plot.
df.plot(x =0, y=[1,2,3,4, 5], xlim=(0,50), ylim=(0.45,0.6))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Load edges.
random_edges = pd.read_csv('out_random_edges.txt', sep='\t', names=['R_sources', 'R_targets'])
print("---RANDOM EDGES---")
print("Unique Sources: ", random_edges['R_sources'].nunique())
print("Unique Targets: ", random_edges['R_targets'].nunique())
print("Average targets per source", random_edges.groupby('R_sources').count().mean())
print("Average sources per target", random_edges.groupby('R_targets').count().mean())
# Out:
# ---RANDOM EDGES---
# Unique Sources:  89
# Unique Targets:  89
# Average targets per source R_targets    3.370787
# dtype: float64
# Average sources per target R_sources    3.370787
# dtype: float64

# %%
print("---PRODUCT EDGES---")
one_edges = pd.read_csv('out_one_edges.txt', sep='\t', names=['1_sources', '1_targets'])
print("Unique Sources: ", one_edges['1_sources'].nunique())
print("Unique Targets: ", one_edges['1_targets'].nunique())
print("Average targets per source", one_edges.groupby('1_sources').count().mean())
print("Average sources per target", one_edges.groupby('1_targets').count().mean())
# Out:
# ---PRODUCT EDGES---
# Unique Sources:  11
# Unique Targets:  43
# Average targets per source 1_targets    27.272727
# dtype: float64
# Average sources per target 1_sources    6.976744
# dtype: float64

# %%
print("---SUM EDGES---")
two_edges = pd.read_csv('out_two_edges.txt', sep='\t', names=['2_sources', '2_targets'])
print("Unque Sources: ", two_edges['2_sources'].nunique())
print("Unique Targets: ", two_edges['2_targets'].nunique())
print("Average targets per source: ", two_edges.groupby("2_sources").count().mean())
print("Average sources per target: ", two_edges.groupby("2_targets").count().mean())
# Out:
# ---SUM EDGES---
# Unque Sources:  54
# Unique Targets:  18
# Average targets per source:  2_targets    5.555556
# dtype: float64
# Average sources per target:  2_sources    16.666667
# dtype: float64

# %%
print("---FORMULA EDGES---")
three_edges = pd.read_csv('out_three_edges.txt', sep ='\t', names=['3_sources', '3_targets'])
print('Unique Sources: ', three_edges['3_sources'].nunique())
print('UNique Targets: ', three_edges['3_targets'].nunique())
print('Average targets per source: ', three_edges.groupby('3_sources').count().mean())
print('Average source per target: ', three_edges.groupby('3_targets').count().mean())
# Out:
# ---FORMULA EDGES---
# Unique Sources:  11
# UNique Targets:  43
# Average targets per source:  3_targets    27.272727
# dtype: float64
# Average source per target:  3_sources    6.976744
# dtype: float64

# %%
print("---FORMULA GREEDY---")
four_edges = pd.read_csv('out_three_greedy_edges.txt', sep ='\t', names=['4_sources', '4_targets'])
print('Unique Sources: ', four_edges['4_sources'].nunique())
print('Unique Targets: ', four_edges['4_targets'].nunique())
print('Average targets per source: ', four_edges.groupby('4_sources').count().mean())
print('Average source per target: ', four_edges.groupby('4_targets').count().mean())
# Out:
# ---FORMULA GREEDY---
# Unique Sources:  56
# Unique Targets:  10
# Average targets per source:  4_targets    5.357143
# dtype: float64
# Average source per target:  4_sources    30.0
# dtype: float64

# %%
top_pg = pd.read_csv('out_top_by_pagerank.txt', sep = '\t')
top_pg['Value'].nunique()
# Out:
# 93

# %%
top_pg.shape
# Out:
# (300, 2)

# %%
top_pg.head()
# Out:
#    Edge     Value
# 0    37  0.028284
# 1    34  0.028003
# 2    50  0.026298
# 3    32  0.026273
# 4    83  0.025128

# %%
dp = top_pg.groupby('Value', as_index=False).count()

# %%
dp.sort_values(by='Edge', ascending=False)
# Out:
#        Value  Edge
# 0   0.000000   208
# 59  0.010238     1
# 68  0.011407     1
# 67  0.011395     1
# 66  0.011366     1
# ..       ...   ...
# 29  0.007001     1
# 28  0.006981     1
# 27  0.006954     1
# 26  0.006952     1
# 92  0.028284     1
#
# [93 rows x 2 columns]

# %%
dp.sort_values(by='Value', ascending=False).head(30)
# Out:
#        Value  Edge
# 92  0.028284     1
# 91  0.028003     1
# 90  0.026298     1
# 89  0.026273     1
# 88  0.025128     1
# 87  0.024099     1
# 86  0.023254     1
# 85  0.022536     1
# 84  0.021690     1
# 83  0.020450     1
# 82  0.020224     1
# 81  0.018873     1
# 80  0.018066     1
# 79  0.017923     1
# 78  0.017371     1
# 77  0.016802     1
# 76  0.016523     1
# 75  0.016242     1
# 74  0.015440     1
# 73  0.014982     1
# 72  0.014335     1
# 71  0.013020     1
# 70  0.011812     1
# 69  0.011422     1
# 68  0.011407     1
# 67  0.011395     1
# 66  0.011366     1
# 65  0.011324     1
# 64  0.011190     1
# 63  0.010522     1

# %%
dp.loc[dp["Edge"] == 1].describe()
# Out:
#            Value  Edge
# count  92.000000  92.0
# mean    0.010870   1.0
# std     0.005991   0.0
# min     0.003793   1.0
# 25%     0.006895   1.0
# 50%     0.008420   1.0
# 75%     0.011519   1.0
# max     0.028284   1.0

# %%
dp.loc[dp['Edge'] > 1].describe()
# Out:
#        Value   Edge
# count    1.0    1.0
# mean     0.0  208.0
# std      NaN    NaN
# min      0.0  208.0
# 25%      0.0  208.0
# 50%      0.0  208.0
# 75%      0.0  208.0
# max      0.0  208.0

# %%
top_redabs = pd.read_csv('out_top_by_redabsprobs.txt', sep='\t')
top_redabs.head()
# Out:
#    Edge     Value
# 0    70  0.973552
# 1    74  0.973014
# 2    72  0.971951
# 3    73  0.970356
# 4    71  0.970019

# %%
top_redabs['Value'].nunique()
# Out:
# 93

# %%
dr = top_redabs.groupby('Value', as_index=False).count()
dr.sort_values(by='Edge', ascending=False)
# Out:
#        Value  Edge
# 0   0.000000   208
# 59  0.915892     1
# 68  0.940277     1
# 67  0.940065     1
# 66  0.938730     1
# ..       ...   ...
# 29  0.030424     1
# 28  0.030159     1
# 27  0.030019     1
# 26  0.029775     1
# 92  0.973552     1
#
# [93 rows x 2 columns]

# %%
dr.sort_values(by='Value', ascending=False).head(30)
# Out:
#        Value  Edge
# 92  0.973552     1
# 91  0.973014     1
# 90  0.971951     1
# 89  0.970356     1
# 88  0.970019     1
# 87  0.969590     1
# 86  0.969433     1
# 85  0.967858     1
# 84  0.966886     1
# 83  0.960795     1
# 82  0.959730     1
# 81  0.959087     1
# 80  0.958770     1
# 79  0.957012     1
# 78  0.955645     1
# 77  0.955506     1
# 76  0.955357     1
# 75  0.953286     1
# 74  0.951733     1
# 73  0.950910     1
# 72  0.948627     1
# 71  0.948515     1
# 70  0.944209     1
# 69  0.942145     1
# 68  0.940277     1
# 67  0.940065     1
# 66  0.938730     1
# 65  0.938125     1
# 64  0.933894     1
# 63  0.929738     1

# %%
dr.loc[dr['Edge'] == 1].describe()
# Out:
#            Value  Edge
# count  92.000000  92.0
# mean    0.471380   1.0
# std     0.439327   0.0
# min     0.016624   1.0
# 25%     0.028675   1.0
# 50%     0.321687   1.0
# 75%     0.942661   1.0
# max     0.973552   1.0

# %%
dr.loc[dr['Edge'] > 1].describe()
# Out:
#        Value   Edge
# count    1.0    1.0
# mean     0.0  208.0
# std      NaN    NaN
# min      0.0  208.0
# 25%      0.0  208.0
# 50%      0.0  208.0
# 75%      0.0  208.0
# max      0.0  208.0
