# %%
# Import needed libraries.
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Nodes to plot/analyze.
nodes = [60, 50, 33]

# %%
# Load 3 for node 0.
df_0 = pd.read_csv('out_greedy_per_one_%d_log.txt' %nodes[0], sep='\t')
# Check load.
#df_0.head()

# %%
# Load 3 for node 1.
df_1 = pd.read_csv('out_greedy_per_one_%d_log.txt' %nodes[1], sep='\t')
# Check load.
#df_1.head()

# %%
# Load 3 for node 2.
df_2 = pd.read_csv('out_greedy_per_one_%d_log.txt' %nodes[2], sep='\t')
# Check load.
#df_2.head()

# %%
# Plot precision plots.
df_0.plot(x=0, y=[1,2,3], kind='line')
df_1.plot(x=0, y=[1,2,3], kind='line')
df_2.plot(x=0, y=[1,2,3], kind='line')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Compare Greedy to Fast Greedy.

# %%
# Load 3 for node 0. Edges and PageRank columns only.
df_a_0 = pd.read_csv('out_greedy_per_one_%d_log.txt' %nodes[0], sep='\t', usecols=[0,1], names=['Edge', 'Pagerank Greedy'], header=0)
df_b_0 = pd.read_csv('out_fast_greedy_per_one_%d_log.txt' %nodes[0], sep='\t', usecols=[0,1], names=['Edge', 'Pagerank Fast Greedy'], header=0)
# Concatenate properly.
df_0 = pd.merge(df_a_0, df_b_0, how='left', on='Edge')
# Check load.
#df_0.head()

# %%
# Load 3 for node 1. Edges and PageRank columns only.
df_a_1 = pd.read_csv('out_greedy_per_one_%d_log.txt' %nodes[1], sep='\t', usecols=[0,1], names=['Edge', 'Pagerank Greedy'], header=0)
df_b_1 = pd.read_csv('out_fast_greedy_per_one_%d_log.txt' %nodes[1], sep='\t', usecols=[0,1], names=['Edge', 'Pagerank Fast Greedy'], header=0)
# Concatenate properly.
df_1 = pd.merge(df_a_1, df_b_1, how='left', on='Edge')
# Check load.
#df_1.head()

# %%
# Load 3 for node 2. Edges and PageRank columns only.
df_a_2 = pd.read_csv('out_greedy_per_one_%d_log.txt' %nodes[2], sep='\t', usecols=[0,1], names=['Edge', 'Pagerank Greedy'], header=0)
df_b_2 = pd.read_csv('out_fast_greedy_per_one_%d_log.txt' %nodes[2], sep='\t', usecols=[0,1], names=['Edge', 'Pagerank Fast Greedy'], header=0)
# Concatenate properly.
df_2 = pd.merge(df_a_2, df_b_2, how='left', on='Edge')
# Check load.
#df_2.head()

# %%
# Plot Greedy vs fast Greedy plots.
df_0.plot(x=0, y=[1,2], kind='line')
df_1.plot(x=0, y=[1,2], kind='line')
df_2.plot(x=0, y=[1,2], kind='line')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Compare Random Algorithms. Edges, Sources.

# %%
# Get average from random edges experiments.
def average_random_edges():
    rnd_edges = np.zeros(300)


    for i in range(10):
        with open("out_random_edges_%d_log.txt" %i, "r") as file_one:
            file_one.readline()
            for j in range(300):
                rnd_edges[j] += float(file_one.readline().split()[1])

    rnd_edges = rnd_edges / 10

    with open("random_edges.txt", "w") as file_one:
        file_one.write("edge\tRed Ratio\n")
        for i in range(300):
            file_one.write("%d\t%f\n" %(i, rnd_edges[i]))
            
average_random_edges()

# %%
# Load random edges.
df_rand_e = pd.read_csv('random_edges.txt', sep='\t', header=0, names=['Edge', 'Pagerank Random Edges'])
# Check load.
#df_rand_e.head()
#df_rand_e.info()

# %%
# Load random source.
df_rand_s = pd.read_csv('out_random_source_all_log.txt', sep='\t', header=0, usecols=[0, 1], names=['Edge', 'Pagerank Random Sources'])
# Check load.
#df_rand_s.head()
#df_rand_s.info()
#df_rand_s.plot(x=0, y=1)

# %%
# Load Greedy.
df_gd = pd.read_csv('out_greedy_all_log.txt', sep='\t', header=0, usecols=[0, 1], names=['Edge', 'Pagerank Greedy'])
# Check load.
#df_gd.head()
#df_gd.info()
#df_gd.plot(x=0, y=1)

# %%
# Merge random properly.
df_rand = pd.merge(df_rand_e, df_rand_s, how='left', on='Edge')
# Check merge.
#df_rand.head()
#df_rand.info()

# %%
# Merge all properly.
df = pd.merge(df_rand, df_gd, how='left', on='Edge')
# Check merge.
#df.head()

# %%
# Plot random stats.
fig = df.plot(x=0, y=[1,2,3], kind='line').get_figure()
fig.savefig("random_three.pdf")
fig.savefig("random_three.png")
# Out:
# <img src="data:image/png;base64,..." width="848">

# %% [markdown]
# ### Analyse Source node's behaviour.

# %%
# Load infos.
df = pd.read_csv('source_node_infos.txt', sep ='\t')
#df.head()

# %%
pd.plotting.scatter_matrix(df)
# Out:
# <img src="data:image/png;base64,..." width="963">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E7537908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E756F288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E75A55C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E75D71C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E760DF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E7649088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E767D848>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E76BB288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E76C0E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E76F7F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E7AE5588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8AF2E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8B257C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8B5D848>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8B95948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8BCDA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8C06B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8C40C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8C78D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8CAFE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8CE8F88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8D250C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8D5D208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8D95308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8DCE388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8E064C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8E3F5C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8E786C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8EB1808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8EE9888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8F20988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8F59AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8F92BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E8FC9CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E9001DC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E903BEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E9072FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E90AF108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E90E8248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E9121308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E9158408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E9191548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E91D0E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E9203748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E923B808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E9274908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E92ADA08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E92E5B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C7E931DC48>]],
#       dtype=object)

# %%
df.plot(x=1, y= 6, kind='scatter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot(x=2, y= 6, kind='scatter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Load graph infos.
pgrnk = pd.read_csv('pagerank.txt', names=['PageRank'])
red_pgrnk = pd.read_csv('red_ratio.txt', names=['Red_Ratio'])
#pgrnk.head()
#red_pgrnk.head()

# %%
pgrnk.plot.hist(bins=500)
# Out:
# <img src="data:image/png;base64,..." width="952">

# %%
red_pgrnk.plot.hist(bins=500)
# Out:
# <img src="data:image/png;base64,..." width="952">
